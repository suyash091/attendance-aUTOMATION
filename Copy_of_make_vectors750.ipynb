# %% [markdown]
# <a href="https://colab.research.google.com/github/suyash091/attendance-aUTOMATION/blob/main/Copy_of_make_vectors750.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install mtcnn
# Out:
# Collecting mtcnn
#   Downloading https://files.pythonhosted.org/packages/67/43/abee91792797c609c1bf30f1112117f7a87a713ebaa6ec5201d5555a73ef/mtcnn-0.1.0-py3-none-any.whl (2.3MB)
#      |████████████████████████████████| 2.3MB 5.7MB/s
# Requirement already satisfied: opencv-python>=4.1.0 in /usr/local/lib/python3.6/dist-packages (from mtcnn) (4.1.2.30)
# Requirement already satisfied: keras>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from mtcnn) (2.4.3)
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.6/dist-packages (from opencv-python>=4.1.0->mtcnn) (1.18.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras>=2.0.0->mtcnn) (3.13)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras>=2.0.0->mtcnn) (2.10.0)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras>=2.0.0->mtcnn) (1.4.1)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from h5py->keras>=2.0.0->mtcnn) (1.15.0)
# Installing collected packages: mtcnn
# Successfully installed mtcnn-0.1.0

# %%
def path_to_image(imgpath):
  img=load_image(imgpath)
  target_size=model.layers[0].input_shape
  target_size = target_size[0][1:3]
  img=align_face(detect_face(img,detector_backend = 'dlib'),detector_backend = 'mtcnn')
  img=cv2.resize(img, (160,160))
  img = image.img_to_array(img)
  img = np.expand_dims(img, axis = 0)
  img /= 255 #normalize input in [0, 1]
  return img

# %%
import numpy as np

def findCosineDistance(source_representation, test_representation):
    a = np.matmul(np.transpose(source_representation), test_representation)
    b = np.sum(np.multiply(source_representation, source_representation))
    c = np.sum(np.multiply(test_representation, test_representation))
    return 1 - (a / (np.sqrt(b) * np.sqrt(c)))

def findEuclideanDistance(source_representation, test_representation):
    euclidean_distance = source_representation - test_representation
    euclidean_distance = np.sum(np.multiply(euclidean_distance, euclidean_distance))
    euclidean_distance = np.sqrt(euclidean_distance)
    return euclidean_distance

def l2_normalize(x):
    return x / np.sqrt(np.sum(np.multiply(x, x)))

# %%
import os
import numpy as np
import pandas as pd
from keras.preprocessing.image import load_img, save_img, img_to_array
from keras.applications.imagenet_utils import preprocess_input
from keras.preprocessing import image
import cv2
from pathlib import Path
import gdown
import hashlib
import math
from PIL import Image
import copy
import base64
import multiprocessing
import subprocess
import tensorflow as tf
import keras
import bz2
#from deepface.commons import distance

def loadBase64Img(uri):
   encoded_data = uri.split(',')[1]
   nparr = np.fromstring(base64.b64decode(encoded_data), np.uint8)
   img = cv2.imdecode(nparr, cv2.IMREAD_COLOR)
   return img

def initializeFolder():
	
	home = str(Path.home())
	
	if not os.path.exists(home+"/.deepface"):
		os.mkdir(home+"/.deepface")
		print("Directory ",home,"/.deepface created")
	
	if not os.path.exists(home+"/.deepface/weights"):
		os.mkdir(home+"/.deepface/weights")
		print("Directory ",home,"/.deepface/weights created")
	
def findThreshold(model_name, distance_metric):
	
	threshold = 0.40
	
	if model_name == 'VGG-Face':
		if distance_metric == 'cosine':
			threshold = 0.40
		elif distance_metric == 'euclidean':
			threshold = 0.55
		elif distance_metric == 'euclidean_l2':
			threshold = 0.75	
	
	elif model_name == 'OpenFace':
		if distance_metric == 'cosine':
			threshold = 0.10
		elif distance_metric == 'euclidean':
			threshold = 0.55
		elif distance_metric == 'euclidean_l2':
			threshold = 0.55
	
	elif model_name == 'Facenet':
		if distance_metric == 'cosine':
			threshold = 0.40
		elif distance_metric == 'euclidean':
			threshold = 10
		elif distance_metric == 'euclidean_l2':
			threshold = 0.80
	
	elif model_name == 'DeepFace':
		if distance_metric == 'cosine':
			threshold = 0.23
		elif distance_metric == 'euclidean':
			threshold = 64
		elif distance_metric == 'euclidean_l2':
			threshold = 0.64
	
	elif model_name == 'DeepID':
		if distance_metric == 'cosine':
			threshold = 0.015
		elif distance_metric == 'euclidean':
			threshold = 45
		elif distance_metric == 'euclidean_l2':
			threshold = 0.17
	
	elif model_name == 'Dlib':
		if distance_metric == 'cosine':
			threshold = 0.07
		elif distance_metric == 'euclidean':
			threshold = 0.60
		elif distance_metric == 'euclidean_l2':
			threshold = 0.60
	
	return threshold

def get_opencv_path():
	opencv_home = cv2.__file__
	folders = opencv_home.split(os.path.sep)[0:-1]
	
	path = folders[0]
	for folder in folders[1:]:
		path = path + "/" + folder
	
	return path+"/data/"

def load_image(img):
	
	exact_image = False
	if type(img).__module__ == np.__name__:
		exact_image = True
	
	base64_img = False
	if len(img) > 11 and img[0:11] == "data:image/":
		base64_img = True
	
	#---------------------------
	
	if base64_img == True:
		img = loadBase64Img(img)
		
	elif exact_image != True: #image path passed as input
		if os.path.isfile(img) != True:
			raise ValueError("Confirm that ",img," exists")
		
		img = cv2.imread(img)
		img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
	return img
	
def detect_face(img, detector_backend = 'opencv', grayscale = False, enforce_detection = True):
	
	home = str(Path.home())
	
	if detector_backend == 'opencv':
	
		#get opencv configuration up first
		opencv_path = get_opencv_path()
		face_detector_path = opencv_path+"haarcascade_frontalface_default.xml"
	
		if os.path.isfile(face_detector_path) != True:
			raise ValueError("Confirm that opencv is installed on your environment! Expected path ",face_detector_path," violated.")
		
		face_detector = cv2.CascadeClassifier(face_detector_path)
	
		#--------------------------
		
		faces = []
		
		try: 
			faces = face_detector.detectMultiScale(img, 1.3, 5)
		except:
			pass
		
		if len(faces) > 0:
			x,y,w,h = faces[0] #focus on the 1st face found in the image
			detected_face = img[int(y):int(y+h), int(x):int(x+w)]
			return detected_face
		
		else: #if no face detected
	
			if enforce_detection != True:			
				return img
	
			else:
				raise ValueError("Face could not be detected. Please confirm that the picture is a face photo or consider to set enforce_detection param to False.")

	elif detector_backend == 'ssd':
		
		#---------------------------
		#check required ssd model exists in the home/.deepface/weights folder
		
		#model structure
		if os.path.isfile(home+'/.deepface/weights/deploy.prototxt') != True:
			
			print("deploy.prototxt will be downloaded...")
			
			url = "https://github.com/opencv/opencv/raw/3.4.0/samples/dnn/face_detector/deploy.prototxt"
			
			output = home+'/.deepface/weights/deploy.prototxt'
			
			gdown.download(url, output, quiet=False)
			
		
		#pre-trained weights
		if os.path.isfile(home+'/.deepface/weights/res10_300x300_ssd_iter_140000.caffemodel') != True:
			
			print("res10_300x300_ssd_iter_140000.caffemodel will be downloaded...")
			
			url = "https://github.com/opencv/opencv_3rdparty/raw/dnn_samples_face_detector_20170830/res10_300x300_ssd_iter_140000.caffemodel"
			
			output = home+'/.deepface/weights/res10_300x300_ssd_iter_140000.caffemodel'
			
			gdown.download(url, output, quiet=False)
			
		#---------------------------
		
		ssd_detector = cv2.dnn.readNetFromCaffe(
			home+"/.deepface/weights/deploy.prototxt", 
			home+"/.deepface/weights/res10_300x300_ssd_iter_140000.caffemodel"
		)
		
		ssd_labels = ["img_id", "is_face", "confidence", "left", "top", "right", "bottom"]
		
		target_size = (300, 300)
		
		base_img = img.copy() #we will restore base_img to img later
		
		original_size = img.shape
		
		img = cv2.resize(img, target_size)
		
		aspect_ratio_x = (original_size[1] / target_size[1])
		aspect_ratio_y = (original_size[0] / target_size[0])
		
		imageBlob = cv2.dnn.blobFromImage(image = img)
		
		ssd_detector.setInput(imageBlob)
		detections = ssd_detector.forward()
		
		detections_df = pd.DataFrame(detections[0][0], columns = ssd_labels)
		
		detections_df = detections_df[detections_df['is_face'] == 1] #0: background, 1: face
		detections_df = detections_df[detections_df['confidence'] >= 0.90]
		
		detections_df['left'] = (detections_df['left'] * 300).astype(int)
		detections_df['bottom'] = (detections_df['bottom'] * 300).astype(int)
		detections_df['right'] = (detections_df['right'] * 300).astype(int)
		detections_df['top'] = (detections_df['top'] * 300).astype(int)
		
		if detections_df.shape[0] > 0:
			
			#TODO: sort detections_df
			
			#get the first face in the image	
			instance = detections_df.iloc[0]
			
			left = instance["left"]
			right = instance["right"]
			bottom = instance["bottom"]
			top = instance["top"]
			
			detected_face = base_img[int(top*aspect_ratio_y):int(bottom*aspect_ratio_y), int(left*aspect_ratio_x):int(right*aspect_ratio_x)]
			
			return detected_face
			
		else: #if no face detected
	
			if enforce_detection != True:
				img = base_img.copy()
				return img
	
			else:
				raise ValueError("Face could not be detected. Please confirm that the picture is a face photo or consider to set enforce_detection param to False.")
	
	elif detector_backend == 'dlib':
		import dlib #this is not a must library within deepface. that's why, I didn't put this import to a global level. version: 19.20.0
		
		detector = dlib.get_frontal_face_detector()
		
		detections = detector(img, 1)
		
		if len(detections) > 0:
			
			for idx, d in enumerate(detections):
				left = d.left(); right = d.right()
				top = d.top(); bottom = d.bottom()
				
				detected_face = img[top:bottom, left:right]
				
				return detected_face
			
		else: #if no face detected
	
			if enforce_detection != True:			
				return img
	
			else:
				raise ValueError("Face could not be detected. Please confirm that the picture is a face photo or consider to set enforce_detection param to False.") 
		
	elif detector_backend == 'mtcnn':
		from mtcnn import MTCNN #0.1.0
		mtcnn_detector = MTCNN()
		
		detections = mtcnn_detector.detect_faces(img)
		
		if len(detections) > 0:
			detection = detections[0]
			x, y, w, h = detection["box"]
			detected_face = img[int(y):int(y+h), int(x):int(x+w)]
			return detected_face
		
		else: #if no face detected
			if enforce_detection != True:			
				return img
	
			else:
				raise ValueError("Face could not be detected. Please confirm that the picture is a face photo or consider to set enforce_detection param to False.")
	
	else:
		detectors = ['opencv', 'ssd', 'dlib', 'mtcnn']
		raise ValueError("Valid backends are ", detectors," but you passed ", detector_backend)
	
	return 0

def alignment_procedure(img, left_eye, right_eye):
		
	#this function aligns given face in img based on left and right eye coordinates
	
	left_eye_x, left_eye_y = left_eye
	right_eye_x, right_eye_y = right_eye
	
	#-----------------------
	#find rotation direction
		
	if left_eye_y > right_eye_y:
		point_3rd = (right_eye_x, left_eye_y)
		direction = -1 #rotate same direction to clock
	else:
		point_3rd = (left_eye_x, right_eye_y)
		direction = 1 #rotate inverse direction of clock
	
	#-----------------------
	#find length of triangle edges
	
	a = findEuclideanDistance(np.array(left_eye), np.array(point_3rd))
	b = findEuclideanDistance(np.array(right_eye), np.array(point_3rd))
	c = findEuclideanDistance(np.array(right_eye), np.array(left_eye))
	
	#-----------------------
	
	#apply cosine rule
			
	if b != 0 and c != 0: #this multiplication causes division by zero in cos_a calculation
		
		cos_a = (b*b + c*c - a*a)/(2*b*c)
		angle = np.arccos(cos_a) #angle in radian
		angle = (angle * 180) / math.pi #radian to degree
		
		#-----------------------
		#rotate base image
		
		if direction == -1:
			angle = 90 - angle
		
		img = Image.fromarray(img)
		img = np.array(img.rotate(direction * angle))
	
	#-----------------------
	
	return img #return img anyway
	
def align_face(img, detector_backend = 'opencv'):
	
	home = str(Path.home())
	
	if (detector_backend == 'opencv') or (detector_backend == 'ssd'):
	
		opencv_path = get_opencv_path()
		eye_detector_path = opencv_path+"haarcascade_eye.xml"
		eye_detector = cv2.CascadeClassifier(eye_detector_path)
		
		detected_face_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY) #eye detector expects gray scale image
		
		eyes = eye_detector.detectMultiScale(detected_face_gray)
		
		if len(eyes) >= 2:
			
			#find the largest 2 eye
			
			base_eyes = eyes[:, 2]
			
			items = []
			for i in range(0, len(base_eyes)):
				item = (base_eyes[i], i)
				items.append(item)
			
			df = pd.DataFrame(items, columns = ["length", "idx"]).sort_values(by=['length'], ascending=False)
			
			eyes = eyes[df.idx.values[0:2]] #eyes variable stores the largest 2 eye
			
			#-----------------------
			#decide left and right eye
			
			eye_1 = eyes[0]; eye_2 = eyes[1]
			
			if eye_1[0] < eye_2[0]:
				left_eye = eye_1; right_eye = eye_2
			else:
				left_eye = eye_2; right_eye = eye_1
			
			#-----------------------
			#find center of eyes
			
			left_eye = (int(left_eye[0] + (left_eye[2] / 2)), int(left_eye[1] + (left_eye[3] / 2)))
			right_eye = (int(right_eye[0] + (right_eye[2]/2)), int(right_eye[1] + (right_eye[3]/2)))
			
			img = alignment_procedure(img, left_eye, right_eye)
			
		return img #return img anyway
	
	elif detector_backend == 'dlib':
	
		#check required file exists in the home/.deepface/weights folder
		
		if os.path.isfile(home+'/.deepface/weights/shape_predictor_5_face_landmarks.dat') != True:
			
			print("shape_predictor_5_face_landmarks.dat.bz2 is going to be downloaded") 
			
			url = "http://dlib.net/files/shape_predictor_5_face_landmarks.dat.bz2"
			output = home+'/.deepface/weights/'+url.split("/")[-1]
			
			gdown.download(url, output, quiet=False)
			
			zipfile = bz2.BZ2File(output)
			data = zipfile.read()
			newfilepath = output[:-4] #discard .bz2 extension
			open(newfilepath, 'wb').write(data)
		
		#------------------------------
		
		import dlib #this is not a must dependency in deepface
		
		detector = dlib.get_frontal_face_detector()
		sp = dlib.shape_predictor(home+"/.deepface/weights/shape_predictor_5_face_landmarks.dat")
		
		detections = detector(img, 1)
		
		if len(detections) > 0:
			detected_face = detections[0]
			img_shape = sp(img, detected_face)
			img = dlib.get_face_chip(img, img_shape, size = img.shape[0])
			
		return img #return img anyway
	
	elif detector_backend == 'mtcnn':
		
		from mtcnn import MTCNN #0.1.0
		mtcnn_detector = MTCNN()
		detections = mtcnn_detector.detect_faces(img)
		
		if len(detections) > 0:
			detection = detections[0]
			
			keypoints = detection["keypoints"]
			left_eye = keypoints["left_eye"]
			right_eye = keypoints["right_eye"]
			
			img = alignment_procedure(img, left_eye, right_eye)
				
		return img #return img anyway
	
def preprocess_face(img, target_size=(224, 224), grayscale = False, enforce_detection = True, detector_backend = 'opencv'):
	
	#img might be path, base64 or numpy array. Convert it to numpy whatever it is.
	img = load_image(img)
	base_img = img.copy()
	
	img = detect_face(img = img, detector_backend = detector_backend, grayscale = grayscale, enforce_detection = enforce_detection)
	
	#--------------------------
	
	if img.shape[0] > 0 and img.shape[1] > 0:
		img = align_face(img = img, detector_backend = detector_backend)
	else:
		
		if enforce_detection == True:
			raise ValueError("Detected face shape is ", img.shape,". Consider to set enforce_detection argument to False.")
		else: #restore base image 
			img = base_img.copy()
		
	#--------------------------
	
	#post-processing
	if grayscale == True:
		img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
		
	img = cv2.resize(img, target_size)
	img_pixels = image.img_to_array(img)
	img_pixels = np.expand_dims(img_pixels, axis = 0)
	img_pixels /= 255 #normalize input in [0, 1]
	
	return img_pixels
	
def allocateMemory():
	
	#find allocated memories
	gpu_indexes = []
	memory_usage_percentages = []; available_memories = []; total_memories = []; utilizations = []
	power_usages = []; power_capacities = []
	
	try:
		result = subprocess.check_output(['nvidia-smi'])

		dashboard = result.decode("utf-8").split("=|")

		dashboard = dashboard[1].split("\n")
		
		gpu_idx = 0
		for line in dashboard:
			if ("MiB" in line):
				power_info = line.split("|")[1]
				power_capacity = int(power_info.split("/")[-1].replace("W", ""))
				power_usage = int((power_info.split("/")[-2]).strip().split(" ")[-1].replace("W", ""))
				
				power_usages.append(power_usage)
				power_capacities.append(power_capacity)
				
				#----------------------------
				
				memory_info = line.split("|")[2].replace("MiB","").split("/")
				utilization_info = int(line.split("|")[3].split("%")[0])
				
				allocated = int(memory_info[0])
				total_memory = int(memory_info[1])
				available_memory = total_memory - allocated
				
				total_memories.append(total_memory)
				available_memories.append(available_memory)
				memory_usage_percentages.append(round(100*int(allocated)/int(total_memory), 4))
				utilizations.append(utilization_info)
				gpu_indexes.append(gpu_idx)
				
				gpu_idx = gpu_idx + 1
		
		gpu_count = gpu_idx * 1
				
	except Exception as err:
		gpu_count = 0
		#print(str(err))
		
	#------------------------------
	
	df = pd.DataFrame(gpu_indexes, columns = ["gpu_index"])
	df["total_memories_in_mb"] = total_memories
	df["available_memories_in_mb"] = available_memories
	df["memory_usage_percentage"] = memory_usage_percentages
	df["utilizations"] = utilizations
	df["power_usages_in_watts"] = power_usages
	df["power_capacities_in_watts"] = power_capacities
	
	df = df.sort_values(by = ["available_memories_in_mb"], ascending = False).reset_index(drop = True)
	
	#------------------------------
	
	required_memory = 10000 #All deepface models require 9016 MiB
	
	if df.shape[0] > 0: #has gpu
		if df.iloc[0].available_memories_in_mb > required_memory:
			my_gpu = str(int(df.iloc[0].gpu_index))
			os.environ["CUDA_VISIBLE_DEVICES"] = my_gpu
			
			#------------------------------
			#tf allocates all memory by default
			#this block avoids greedy approach
			
			config = tf.ConfigProto()
			config.gpu_options.allow_growth = True
			session = tf.Session(config=config)
			keras.backend.set_session(session)
			
			print("DeepFace will run on GPU (gpu_", my_gpu,")")
		else:
			#this case has gpu but no enough memory to allocate
			os.environ["CUDA_VISIBLE_DEVICES"] = "" #run it on cpu
			print("Even though the system has GPUs, there is no enough space in memory to allocate.")
			print("DeepFace will run on CPU")
	else:
		print("DeepFace will run on CPU")

# %%
import os
from pathlib import Path
import gdown
from functools import partial

from keras.models import Model
from keras.layers import Activation
from keras.layers import BatchNormalization
from keras.layers import Concatenate
from keras.layers import Conv2D
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import GlobalAveragePooling2D
from keras.layers import Input
from keras.layers import Lambda
from keras.layers import MaxPooling2D
from keras.layers import add
from keras import backend as K

def scaling(x, scale):
	return x * scale

def InceptionResNetV2():
	
	inputs = Input(shape=(160, 160, 3))
	x = Conv2D(32, 3, strides=2, padding='valid', use_bias=False, name= 'Conv2d_1a_3x3') (inputs)
	x = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Conv2d_1a_3x3_BatchNorm')(x)
	x = Activation('relu', name='Conv2d_1a_3x3_Activation')(x)
	x = Conv2D(32, 3, strides=1, padding='valid', use_bias=False, name= 'Conv2d_2a_3x3') (x)
	x = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Conv2d_2a_3x3_BatchNorm')(x)
	x = Activation('relu', name='Conv2d_2a_3x3_Activation')(x)
	x = Conv2D(64, 3, strides=1, padding='same', use_bias=False, name= 'Conv2d_2b_3x3') (x)
	x = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Conv2d_2b_3x3_BatchNorm')(x)
	x = Activation('relu', name='Conv2d_2b_3x3_Activation')(x)
	x = MaxPooling2D(3, strides=2, name='MaxPool_3a_3x3')(x)
	x = Conv2D(80, 1, strides=1, padding='valid', use_bias=False, name= 'Conv2d_3b_1x1') (x)
	x = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Conv2d_3b_1x1_BatchNorm')(x)
	x = Activation('relu', name='Conv2d_3b_1x1_Activation')(x)
	x = Conv2D(192, 3, strides=1, padding='valid', use_bias=False, name= 'Conv2d_4a_3x3') (x)
	x = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Conv2d_4a_3x3_BatchNorm')(x)
	x = Activation('relu', name='Conv2d_4a_3x3_Activation')(x)
	x = Conv2D(256, 3, strides=2, padding='valid', use_bias=False, name= 'Conv2d_4b_3x3') (x)
	x = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Conv2d_4b_3x3_BatchNorm')(x)
	x = Activation('relu', name='Conv2d_4b_3x3_Activation')(x)
	
	# 5x Block35 (Inception-ResNet-A block):
	branch_0 = Conv2D(32, 1, strides=1, padding='same', use_bias=False, name= 'Block35_1_Branch_0_Conv2d_1x1') (x)
	branch_0 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block35_1_Branch_0_Conv2d_1x1_BatchNorm')(branch_0)
	branch_0 = Activation('relu', name='Block35_1_Branch_0_Conv2d_1x1_Activation')(branch_0)
	branch_1 = Conv2D(32, 1, strides=1, padding='same', use_bias=False, name= 'Block35_1_Branch_1_Conv2d_0a_1x1') (x)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block35_1_Branch_1_Conv2d_0a_1x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block35_1_Branch_1_Conv2d_0a_1x1_Activation')(branch_1)
	branch_1 = Conv2D(32, 3, strides=1, padding='same', use_bias=False, name= 'Block35_1_Branch_1_Conv2d_0b_3x3') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block35_1_Branch_1_Conv2d_0b_3x3_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block35_1_Branch_1_Conv2d_0b_3x3_Activation')(branch_1)
	branch_2 = Conv2D(32, 1, strides=1, padding='same', use_bias=False, name= 'Block35_1_Branch_2_Conv2d_0a_1x1') (x)
	branch_2 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block35_1_Branch_2_Conv2d_0a_1x1_BatchNorm')(branch_2)
	branch_2 = Activation('relu', name='Block35_1_Branch_2_Conv2d_0a_1x1_Activation')(branch_2)
	branch_2 = Conv2D(32, 3, strides=1, padding='same', use_bias=False, name= 'Block35_1_Branch_2_Conv2d_0b_3x3') (branch_2)
	branch_2 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block35_1_Branch_2_Conv2d_0b_3x3_BatchNorm')(branch_2)
	branch_2 = Activation('relu', name='Block35_1_Branch_2_Conv2d_0b_3x3_Activation')(branch_2)
	branch_2 = Conv2D(32, 3, strides=1, padding='same', use_bias=False, name= 'Block35_1_Branch_2_Conv2d_0c_3x3') (branch_2)
	branch_2 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block35_1_Branch_2_Conv2d_0c_3x3_BatchNorm')(branch_2)
	branch_2 = Activation('relu', name='Block35_1_Branch_2_Conv2d_0c_3x3_Activation')(branch_2)
	branches = [branch_0, branch_1, branch_2]
	mixed = Concatenate(axis=3, name='Block35_1_Concatenate')(branches)
	up = Conv2D(256, 1, strides=1, padding='same', use_bias=True, name= 'Block35_1_Conv2d_1x1') (mixed)
	up = Lambda(scaling, output_shape=K.int_shape(up)[1:], arguments={'scale': 0.17})(up)
	x = add([x, up])
	x = Activation('relu', name='Block35_1_Activation')(x)
	
	branch_0 = Conv2D(32, 1, strides=1, padding='same', use_bias=False, name= 'Block35_2_Branch_0_Conv2d_1x1') (x)
	branch_0 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block35_2_Branch_0_Conv2d_1x1_BatchNorm')(branch_0)
	branch_0 = Activation('relu', name='Block35_2_Branch_0_Conv2d_1x1_Activation')(branch_0)
	branch_1 = Conv2D(32, 1, strides=1, padding='same', use_bias=False, name= 'Block35_2_Branch_1_Conv2d_0a_1x1') (x)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block35_2_Branch_1_Conv2d_0a_1x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block35_2_Branch_1_Conv2d_0a_1x1_Activation')(branch_1)
	branch_1 = Conv2D(32, 3, strides=1, padding='same', use_bias=False, name= 'Block35_2_Branch_1_Conv2d_0b_3x3') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block35_2_Branch_1_Conv2d_0b_3x3_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block35_2_Branch_1_Conv2d_0b_3x3_Activation')(branch_1)
	branch_2 = Conv2D(32, 1, strides=1, padding='same', use_bias=False, name= 'Block35_2_Branch_2_Conv2d_0a_1x1') (x)
	branch_2 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block35_2_Branch_2_Conv2d_0a_1x1_BatchNorm')(branch_2)
	branch_2 = Activation('relu', name='Block35_2_Branch_2_Conv2d_0a_1x1_Activation')(branch_2)
	branch_2 = Conv2D(32, 3, strides=1, padding='same', use_bias=False, name= 'Block35_2_Branch_2_Conv2d_0b_3x3') (branch_2)
	branch_2 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block35_2_Branch_2_Conv2d_0b_3x3_BatchNorm')(branch_2)
	branch_2 = Activation('relu', name='Block35_2_Branch_2_Conv2d_0b_3x3_Activation')(branch_2)
	branch_2 = Conv2D(32, 3, strides=1, padding='same', use_bias=False, name= 'Block35_2_Branch_2_Conv2d_0c_3x3') (branch_2)
	branch_2 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block35_2_Branch_2_Conv2d_0c_3x3_BatchNorm')(branch_2)
	branch_2 = Activation('relu', name='Block35_2_Branch_2_Conv2d_0c_3x3_Activation')(branch_2)
	branches = [branch_0, branch_1, branch_2]
	mixed = Concatenate(axis=3, name='Block35_2_Concatenate')(branches)
	up = Conv2D(256, 1, strides=1, padding='same', use_bias=True, name= 'Block35_2_Conv2d_1x1') (mixed)
	up = Lambda(scaling, output_shape=K.int_shape(up)[1:], arguments={'scale': 0.17})(up)
	x = add([x, up])
	x = Activation('relu', name='Block35_2_Activation')(x)
	
	branch_0 = Conv2D(32, 1, strides=1, padding='same', use_bias=False, name= 'Block35_3_Branch_0_Conv2d_1x1') (x)
	branch_0 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block35_3_Branch_0_Conv2d_1x1_BatchNorm')(branch_0)
	branch_0 = Activation('relu', name='Block35_3_Branch_0_Conv2d_1x1_Activation')(branch_0)
	branch_1 = Conv2D(32, 1, strides=1, padding='same', use_bias=False, name= 'Block35_3_Branch_1_Conv2d_0a_1x1') (x)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block35_3_Branch_1_Conv2d_0a_1x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block35_3_Branch_1_Conv2d_0a_1x1_Activation')(branch_1)
	branch_1 = Conv2D(32, 3, strides=1, padding='same', use_bias=False, name= 'Block35_3_Branch_1_Conv2d_0b_3x3') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block35_3_Branch_1_Conv2d_0b_3x3_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block35_3_Branch_1_Conv2d_0b_3x3_Activation')(branch_1)
	branch_2 = Conv2D(32, 1, strides=1, padding='same', use_bias=False, name= 'Block35_3_Branch_2_Conv2d_0a_1x1') (x)
	branch_2 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block35_3_Branch_2_Conv2d_0a_1x1_BatchNorm')(branch_2)
	branch_2 = Activation('relu', name='Block35_3_Branch_2_Conv2d_0a_1x1_Activation')(branch_2)
	branch_2 = Conv2D(32, 3, strides=1, padding='same', use_bias=False, name= 'Block35_3_Branch_2_Conv2d_0b_3x3') (branch_2)
	branch_2 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block35_3_Branch_2_Conv2d_0b_3x3_BatchNorm')(branch_2)
	branch_2 = Activation('relu', name='Block35_3_Branch_2_Conv2d_0b_3x3_Activation')(branch_2)
	branch_2 = Conv2D(32, 3, strides=1, padding='same', use_bias=False, name= 'Block35_3_Branch_2_Conv2d_0c_3x3') (branch_2)
	branch_2 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block35_3_Branch_2_Conv2d_0c_3x3_BatchNorm')(branch_2)
	branch_2 = Activation('relu', name='Block35_3_Branch_2_Conv2d_0c_3x3_Activation')(branch_2)
	branches = [branch_0, branch_1, branch_2]
	mixed = Concatenate(axis=3, name='Block35_3_Concatenate')(branches)
	up = Conv2D(256, 1, strides=1, padding='same', use_bias=True, name= 'Block35_3_Conv2d_1x1') (mixed)
	up = Lambda(scaling, output_shape=K.int_shape(up)[1:], arguments={'scale': 0.17})(up)
	x = add([x, up])
	x = Activation('relu', name='Block35_3_Activation')(x)
	
	branch_0 = Conv2D(32, 1, strides=1, padding='same', use_bias=False, name= 'Block35_4_Branch_0_Conv2d_1x1') (x)
	branch_0 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block35_4_Branch_0_Conv2d_1x1_BatchNorm')(branch_0)
	branch_0 = Activation('relu', name='Block35_4_Branch_0_Conv2d_1x1_Activation')(branch_0)
	branch_1 = Conv2D(32, 1, strides=1, padding='same', use_bias=False, name= 'Block35_4_Branch_1_Conv2d_0a_1x1') (x)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block35_4_Branch_1_Conv2d_0a_1x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block35_4_Branch_1_Conv2d_0a_1x1_Activation')(branch_1)
	branch_1 = Conv2D(32, 3, strides=1, padding='same', use_bias=False, name= 'Block35_4_Branch_1_Conv2d_0b_3x3') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block35_4_Branch_1_Conv2d_0b_3x3_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block35_4_Branch_1_Conv2d_0b_3x3_Activation')(branch_1)
	branch_2 = Conv2D(32, 1, strides=1, padding='same', use_bias=False, name= 'Block35_4_Branch_2_Conv2d_0a_1x1') (x)
	branch_2 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block35_4_Branch_2_Conv2d_0a_1x1_BatchNorm')(branch_2)
	branch_2 = Activation('relu', name='Block35_4_Branch_2_Conv2d_0a_1x1_Activation')(branch_2)
	branch_2 = Conv2D(32, 3, strides=1, padding='same', use_bias=False, name= 'Block35_4_Branch_2_Conv2d_0b_3x3') (branch_2)
	branch_2 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block35_4_Branch_2_Conv2d_0b_3x3_BatchNorm')(branch_2)
	branch_2 = Activation('relu', name='Block35_4_Branch_2_Conv2d_0b_3x3_Activation')(branch_2)
	branch_2 = Conv2D(32, 3, strides=1, padding='same', use_bias=False, name= 'Block35_4_Branch_2_Conv2d_0c_3x3') (branch_2)
	branch_2 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block35_4_Branch_2_Conv2d_0c_3x3_BatchNorm')(branch_2)
	branch_2 = Activation('relu', name='Block35_4_Branch_2_Conv2d_0c_3x3_Activation')(branch_2)
	branches = [branch_0, branch_1, branch_2]
	mixed = Concatenate(axis=3, name='Block35_4_Concatenate')(branches)
	up = Conv2D(256, 1, strides=1, padding='same', use_bias=True, name= 'Block35_4_Conv2d_1x1') (mixed)
	up = Lambda(scaling, output_shape=K.int_shape(up)[1:], arguments={'scale': 0.17})(up)
	x = add([x, up])
	x = Activation('relu', name='Block35_4_Activation')(x)
	
	branch_0 = Conv2D(32, 1, strides=1, padding='same', use_bias=False, name= 'Block35_5_Branch_0_Conv2d_1x1') (x)
	branch_0 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block35_5_Branch_0_Conv2d_1x1_BatchNorm')(branch_0)
	branch_0 = Activation('relu', name='Block35_5_Branch_0_Conv2d_1x1_Activation')(branch_0)
	branch_1 = Conv2D(32, 1, strides=1, padding='same', use_bias=False, name= 'Block35_5_Branch_1_Conv2d_0a_1x1') (x)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block35_5_Branch_1_Conv2d_0a_1x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block35_5_Branch_1_Conv2d_0a_1x1_Activation')(branch_1)
	branch_1 = Conv2D(32, 3, strides=1, padding='same', use_bias=False, name= 'Block35_5_Branch_1_Conv2d_0b_3x3') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block35_5_Branch_1_Conv2d_0b_3x3_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block35_5_Branch_1_Conv2d_0b_3x3_Activation')(branch_1)
	branch_2 = Conv2D(32, 1, strides=1, padding='same', use_bias=False, name= 'Block35_5_Branch_2_Conv2d_0a_1x1') (x)
	branch_2 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block35_5_Branch_2_Conv2d_0a_1x1_BatchNorm')(branch_2)
	branch_2 = Activation('relu', name='Block35_5_Branch_2_Conv2d_0a_1x1_Activation')(branch_2)
	branch_2 = Conv2D(32, 3, strides=1, padding='same', use_bias=False, name= 'Block35_5_Branch_2_Conv2d_0b_3x3') (branch_2)
	branch_2 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block35_5_Branch_2_Conv2d_0b_3x3_BatchNorm')(branch_2)
	branch_2 = Activation('relu', name='Block35_5_Branch_2_Conv2d_0b_3x3_Activation')(branch_2)
	branch_2 = Conv2D(32, 3, strides=1, padding='same', use_bias=False, name= 'Block35_5_Branch_2_Conv2d_0c_3x3') (branch_2)
	branch_2 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block35_5_Branch_2_Conv2d_0c_3x3_BatchNorm')(branch_2)
	branch_2 = Activation('relu', name='Block35_5_Branch_2_Conv2d_0c_3x3_Activation')(branch_2)
	branches = [branch_0, branch_1, branch_2]
	mixed = Concatenate(axis=3, name='Block35_5_Concatenate')(branches)
	up = Conv2D(256, 1, strides=1, padding='same', use_bias=True, name= 'Block35_5_Conv2d_1x1') (mixed)
	up = Lambda(scaling, output_shape=K.int_shape(up)[1:], arguments={'scale': 0.17})(up)
	x = add([x, up])
	x = Activation('relu', name='Block35_5_Activation')(x)

	# Mixed 6a (Reduction-A block):
	branch_0 = Conv2D(384, 3, strides=2, padding='valid', use_bias=False, name= 'Mixed_6a_Branch_0_Conv2d_1a_3x3') (x)
	branch_0 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Mixed_6a_Branch_0_Conv2d_1a_3x3_BatchNorm')(branch_0)
	branch_0 = Activation('relu', name='Mixed_6a_Branch_0_Conv2d_1a_3x3_Activation')(branch_0)
	branch_1 = Conv2D(192, 1, strides=1, padding='same', use_bias=False, name= 'Mixed_6a_Branch_1_Conv2d_0a_1x1') (x)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Mixed_6a_Branch_1_Conv2d_0a_1x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Mixed_6a_Branch_1_Conv2d_0a_1x1_Activation')(branch_1)
	branch_1 = Conv2D(192, 3, strides=1, padding='same', use_bias=False, name= 'Mixed_6a_Branch_1_Conv2d_0b_3x3') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Mixed_6a_Branch_1_Conv2d_0b_3x3_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Mixed_6a_Branch_1_Conv2d_0b_3x3_Activation')(branch_1)
	branch_1 = Conv2D(256, 3, strides=2, padding='valid', use_bias=False, name= 'Mixed_6a_Branch_1_Conv2d_1a_3x3') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Mixed_6a_Branch_1_Conv2d_1a_3x3_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Mixed_6a_Branch_1_Conv2d_1a_3x3_Activation')(branch_1)
	branch_pool = MaxPooling2D(3, strides=2, padding='valid', name='Mixed_6a_Branch_2_MaxPool_1a_3x3')(x)
	branches = [branch_0, branch_1, branch_pool]
	x = Concatenate(axis=3, name='Mixed_6a')(branches)

	# 10x Block17 (Inception-ResNet-B block):
	branch_0 = Conv2D(128, 1, strides=1, padding='same', use_bias=False, name= 'Block17_1_Branch_0_Conv2d_1x1') (x)
	branch_0 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_1_Branch_0_Conv2d_1x1_BatchNorm')(branch_0)
	branch_0 = Activation('relu', name='Block17_1_Branch_0_Conv2d_1x1_Activation')(branch_0)
	branch_1 = Conv2D(128, 1, strides=1, padding='same', use_bias=False, name= 'Block17_1_Branch_1_Conv2d_0a_1x1') (x)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_1_Branch_1_Conv2d_0a_1x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block17_1_Branch_1_Conv2d_0a_1x1_Activation')(branch_1)
	branch_1 = Conv2D(128, [1, 7], strides=1, padding='same', use_bias=False, name= 'Block17_1_Branch_1_Conv2d_0b_1x7') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_1_Branch_1_Conv2d_0b_1x7_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block17_1_Branch_1_Conv2d_0b_1x7_Activation')(branch_1)
	branch_1 = Conv2D(128, [7, 1], strides=1, padding='same', use_bias=False, name= 'Block17_1_Branch_1_Conv2d_0c_7x1') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_1_Branch_1_Conv2d_0c_7x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block17_1_Branch_1_Conv2d_0c_7x1_Activation')(branch_1)
	branches = [branch_0, branch_1]
	mixed = Concatenate(axis=3, name='Block17_1_Concatenate')(branches)
	up = Conv2D(896, 1, strides=1, padding='same', use_bias=True, name= 'Block17_1_Conv2d_1x1') (mixed)
	up = Lambda(scaling, output_shape=K.int_shape(up)[1:], arguments={'scale': 0.1})(up)
	x = add([x, up])
	x = Activation('relu', name='Block17_1_Activation')(x)
	
	branch_0 = Conv2D(128, 1, strides=1, padding='same', use_bias=False, name= 'Block17_2_Branch_0_Conv2d_1x1') (x)
	branch_0 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_2_Branch_0_Conv2d_1x1_BatchNorm')(branch_0)
	branch_0 = Activation('relu', name='Block17_2_Branch_0_Conv2d_1x1_Activation')(branch_0)
	branch_1 = Conv2D(128, 1, strides=1, padding='same', use_bias=False, name= 'Block17_2_Branch_2_Conv2d_0a_1x1') (x)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_2_Branch_2_Conv2d_0a_1x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block17_2_Branch_2_Conv2d_0a_1x1_Activation')(branch_1)
	branch_1 = Conv2D(128, [1, 7], strides=1, padding='same', use_bias=False, name= 'Block17_2_Branch_2_Conv2d_0b_1x7') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_2_Branch_2_Conv2d_0b_1x7_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block17_2_Branch_2_Conv2d_0b_1x7_Activation')(branch_1)
	branch_1 = Conv2D(128, [7, 1], strides=1, padding='same', use_bias=False, name= 'Block17_2_Branch_2_Conv2d_0c_7x1') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_2_Branch_2_Conv2d_0c_7x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block17_2_Branch_2_Conv2d_0c_7x1_Activation')(branch_1)
	branches = [branch_0, branch_1]
	mixed = Concatenate(axis=3, name='Block17_2_Concatenate')(branches)
	up = Conv2D(896, 1, strides=1, padding='same', use_bias=True, name= 'Block17_2_Conv2d_1x1') (mixed)
	up = Lambda(scaling, output_shape=K.int_shape(up)[1:], arguments={'scale': 0.1})(up)
	x = add([x, up])
	x = Activation('relu', name='Block17_2_Activation')(x)
	
	branch_0 = Conv2D(128, 1, strides=1, padding='same', use_bias=False, name= 'Block17_3_Branch_0_Conv2d_1x1') (x)
	branch_0 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_3_Branch_0_Conv2d_1x1_BatchNorm')(branch_0)
	branch_0 = Activation('relu', name='Block17_3_Branch_0_Conv2d_1x1_Activation')(branch_0)
	branch_1 = Conv2D(128, 1, strides=1, padding='same', use_bias=False, name= 'Block17_3_Branch_3_Conv2d_0a_1x1') (x)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_3_Branch_3_Conv2d_0a_1x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block17_3_Branch_3_Conv2d_0a_1x1_Activation')(branch_1)
	branch_1 = Conv2D(128, [1, 7], strides=1, padding='same', use_bias=False, name= 'Block17_3_Branch_3_Conv2d_0b_1x7') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_3_Branch_3_Conv2d_0b_1x7_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block17_3_Branch_3_Conv2d_0b_1x7_Activation')(branch_1)
	branch_1 = Conv2D(128, [7, 1], strides=1, padding='same', use_bias=False, name= 'Block17_3_Branch_3_Conv2d_0c_7x1') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_3_Branch_3_Conv2d_0c_7x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block17_3_Branch_3_Conv2d_0c_7x1_Activation')(branch_1)
	branches = [branch_0, branch_1]
	mixed = Concatenate(axis=3, name='Block17_3_Concatenate')(branches)
	up = Conv2D(896, 1, strides=1, padding='same', use_bias=True, name= 'Block17_3_Conv2d_1x1') (mixed)
	up = Lambda(scaling, output_shape=K.int_shape(up)[1:], arguments={'scale': 0.1})(up)
	x = add([x, up])
	x = Activation('relu', name='Block17_3_Activation')(x)
	
	branch_0 = Conv2D(128, 1, strides=1, padding='same', use_bias=False, name= 'Block17_4_Branch_0_Conv2d_1x1') (x)
	branch_0 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_4_Branch_0_Conv2d_1x1_BatchNorm')(branch_0)
	branch_0 = Activation('relu', name='Block17_4_Branch_0_Conv2d_1x1_Activation')(branch_0)
	branch_1 = Conv2D(128, 1, strides=1, padding='same', use_bias=False, name= 'Block17_4_Branch_4_Conv2d_0a_1x1') (x)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_4_Branch_4_Conv2d_0a_1x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block17_4_Branch_4_Conv2d_0a_1x1_Activation')(branch_1)
	branch_1 = Conv2D(128, [1, 7], strides=1, padding='same', use_bias=False, name= 'Block17_4_Branch_4_Conv2d_0b_1x7') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_4_Branch_4_Conv2d_0b_1x7_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block17_4_Branch_4_Conv2d_0b_1x7_Activation')(branch_1)
	branch_1 = Conv2D(128, [7, 1], strides=1, padding='same', use_bias=False, name= 'Block17_4_Branch_4_Conv2d_0c_7x1') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_4_Branch_4_Conv2d_0c_7x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block17_4_Branch_4_Conv2d_0c_7x1_Activation')(branch_1)
	branches = [branch_0, branch_1]
	mixed = Concatenate(axis=3, name='Block17_4_Concatenate')(branches)
	up = Conv2D(896, 1, strides=1, padding='same', use_bias=True, name= 'Block17_4_Conv2d_1x1') (mixed)
	up = Lambda(scaling, output_shape=K.int_shape(up)[1:], arguments={'scale': 0.1})(up)
	x = add([x, up])
	x = Activation('relu', name='Block17_4_Activation')(x)
	
	branch_0 = Conv2D(128, 1, strides=1, padding='same', use_bias=False, name= 'Block17_5_Branch_0_Conv2d_1x1') (x)
	branch_0 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_5_Branch_0_Conv2d_1x1_BatchNorm')(branch_0)
	branch_0 = Activation('relu', name='Block17_5_Branch_0_Conv2d_1x1_Activation')(branch_0)
	branch_1 = Conv2D(128, 1, strides=1, padding='same', use_bias=False, name= 'Block17_5_Branch_5_Conv2d_0a_1x1') (x)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_5_Branch_5_Conv2d_0a_1x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block17_5_Branch_5_Conv2d_0a_1x1_Activation')(branch_1)
	branch_1 = Conv2D(128, [1, 7], strides=1, padding='same', use_bias=False, name= 'Block17_5_Branch_5_Conv2d_0b_1x7') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_5_Branch_5_Conv2d_0b_1x7_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block17_5_Branch_5_Conv2d_0b_1x7_Activation')(branch_1)
	branch_1 = Conv2D(128, [7, 1], strides=1, padding='same', use_bias=False, name= 'Block17_5_Branch_5_Conv2d_0c_7x1') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_5_Branch_5_Conv2d_0c_7x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block17_5_Branch_5_Conv2d_0c_7x1_Activation')(branch_1)
	branches = [branch_0, branch_1]
	mixed = Concatenate(axis=3, name='Block17_5_Concatenate')(branches)
	up = Conv2D(896, 1, strides=1, padding='same', use_bias=True, name= 'Block17_5_Conv2d_1x1') (mixed)
	up = Lambda(scaling, output_shape=K.int_shape(up)[1:], arguments={'scale': 0.1})(up)
	x = add([x, up])
	x = Activation('relu', name='Block17_5_Activation')(x)
	
	branch_0 = Conv2D(128, 1, strides=1, padding='same', use_bias=False, name= 'Block17_6_Branch_0_Conv2d_1x1') (x)
	branch_0 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_6_Branch_0_Conv2d_1x1_BatchNorm')(branch_0)
	branch_0 = Activation('relu', name='Block17_6_Branch_0_Conv2d_1x1_Activation')(branch_0)
	branch_1 = Conv2D(128, 1, strides=1, padding='same', use_bias=False, name= 'Block17_6_Branch_6_Conv2d_0a_1x1') (x)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_6_Branch_6_Conv2d_0a_1x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block17_6_Branch_6_Conv2d_0a_1x1_Activation')(branch_1)
	branch_1 = Conv2D(128, [1, 7], strides=1, padding='same', use_bias=False, name= 'Block17_6_Branch_6_Conv2d_0b_1x7') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_6_Branch_6_Conv2d_0b_1x7_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block17_6_Branch_6_Conv2d_0b_1x7_Activation')(branch_1)
	branch_1 = Conv2D(128, [7, 1], strides=1, padding='same', use_bias=False, name= 'Block17_6_Branch_6_Conv2d_0c_7x1') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_6_Branch_6_Conv2d_0c_7x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block17_6_Branch_6_Conv2d_0c_7x1_Activation')(branch_1)
	branches = [branch_0, branch_1]
	mixed = Concatenate(axis=3, name='Block17_6_Concatenate')(branches)
	up = Conv2D(896, 1, strides=1, padding='same', use_bias=True, name= 'Block17_6_Conv2d_1x1') (mixed)
	up = Lambda(scaling, output_shape=K.int_shape(up)[1:], arguments={'scale': 0.1})(up)
	x = add([x, up])
	x = Activation('relu', name='Block17_6_Activation')(x)	
	
	branch_0 = Conv2D(128, 1, strides=1, padding='same', use_bias=False, name= 'Block17_7_Branch_0_Conv2d_1x1') (x)
	branch_0 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_7_Branch_0_Conv2d_1x1_BatchNorm')(branch_0)
	branch_0 = Activation('relu', name='Block17_7_Branch_0_Conv2d_1x1_Activation')(branch_0)
	branch_1 = Conv2D(128, 1, strides=1, padding='same', use_bias=False, name= 'Block17_7_Branch_7_Conv2d_0a_1x1') (x)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_7_Branch_7_Conv2d_0a_1x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block17_7_Branch_7_Conv2d_0a_1x1_Activation')(branch_1)
	branch_1 = Conv2D(128, [1, 7], strides=1, padding='same', use_bias=False, name= 'Block17_7_Branch_7_Conv2d_0b_1x7') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_7_Branch_7_Conv2d_0b_1x7_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block17_7_Branch_7_Conv2d_0b_1x7_Activation')(branch_1)
	branch_1 = Conv2D(128, [7, 1], strides=1, padding='same', use_bias=False, name= 'Block17_7_Branch_7_Conv2d_0c_7x1') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_7_Branch_7_Conv2d_0c_7x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block17_7_Branch_7_Conv2d_0c_7x1_Activation')(branch_1)
	branches = [branch_0, branch_1]
	mixed = Concatenate(axis=3, name='Block17_7_Concatenate')(branches)
	up = Conv2D(896, 1, strides=1, padding='same', use_bias=True, name= 'Block17_7_Conv2d_1x1') (mixed)
	up = Lambda(scaling, output_shape=K.int_shape(up)[1:], arguments={'scale': 0.1})(up)
	x = add([x, up])
	x = Activation('relu', name='Block17_7_Activation')(x)
	
	branch_0 = Conv2D(128, 1, strides=1, padding='same', use_bias=False, name= 'Block17_8_Branch_0_Conv2d_1x1') (x)
	branch_0 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_8_Branch_0_Conv2d_1x1_BatchNorm')(branch_0)
	branch_0 = Activation('relu', name='Block17_8_Branch_0_Conv2d_1x1_Activation')(branch_0)
	branch_1 = Conv2D(128, 1, strides=1, padding='same', use_bias=False, name= 'Block17_8_Branch_8_Conv2d_0a_1x1') (x)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_8_Branch_8_Conv2d_0a_1x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block17_8_Branch_8_Conv2d_0a_1x1_Activation')(branch_1)
	branch_1 = Conv2D(128, [1, 7], strides=1, padding='same', use_bias=False, name= 'Block17_8_Branch_8_Conv2d_0b_1x7') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_8_Branch_8_Conv2d_0b_1x7_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block17_8_Branch_8_Conv2d_0b_1x7_Activation')(branch_1)
	branch_1 = Conv2D(128, [7, 1], strides=1, padding='same', use_bias=False, name= 'Block17_8_Branch_8_Conv2d_0c_7x1') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_8_Branch_8_Conv2d_0c_7x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block17_8_Branch_8_Conv2d_0c_7x1_Activation')(branch_1)
	branches = [branch_0, branch_1]
	mixed = Concatenate(axis=3, name='Block17_8_Concatenate')(branches)
	up = Conv2D(896, 1, strides=1, padding='same', use_bias=True, name= 'Block17_8_Conv2d_1x1') (mixed)
	up = Lambda(scaling, output_shape=K.int_shape(up)[1:], arguments={'scale': 0.1})(up)
	x = add([x, up])
	x = Activation('relu', name='Block17_8_Activation')(x)
	
	branch_0 = Conv2D(128, 1, strides=1, padding='same', use_bias=False, name= 'Block17_9_Branch_0_Conv2d_1x1') (x)
	branch_0 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_9_Branch_0_Conv2d_1x1_BatchNorm')(branch_0)
	branch_0 = Activation('relu', name='Block17_9_Branch_0_Conv2d_1x1_Activation')(branch_0)
	branch_1 = Conv2D(128, 1, strides=1, padding='same', use_bias=False, name= 'Block17_9_Branch_9_Conv2d_0a_1x1') (x)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_9_Branch_9_Conv2d_0a_1x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block17_9_Branch_9_Conv2d_0a_1x1_Activation')(branch_1)
	branch_1 = Conv2D(128, [1, 7], strides=1, padding='same', use_bias=False, name= 'Block17_9_Branch_9_Conv2d_0b_1x7') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_9_Branch_9_Conv2d_0b_1x7_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block17_9_Branch_9_Conv2d_0b_1x7_Activation')(branch_1)
	branch_1 = Conv2D(128, [7, 1], strides=1, padding='same', use_bias=False, name= 'Block17_9_Branch_9_Conv2d_0c_7x1') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_9_Branch_9_Conv2d_0c_7x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block17_9_Branch_9_Conv2d_0c_7x1_Activation')(branch_1)
	branches = [branch_0, branch_1]
	mixed = Concatenate(axis=3, name='Block17_9_Concatenate')(branches)
	up = Conv2D(896, 1, strides=1, padding='same', use_bias=True, name= 'Block17_9_Conv2d_1x1') (mixed)
	up = Lambda(scaling, output_shape=K.int_shape(up)[1:], arguments={'scale': 0.1})(up)
	x = add([x, up])
	x = Activation('relu', name='Block17_9_Activation')(x)
	
	branch_0 = Conv2D(128, 1, strides=1, padding='same', use_bias=False, name= 'Block17_10_Branch_0_Conv2d_1x1') (x)
	branch_0 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_10_Branch_0_Conv2d_1x1_BatchNorm')(branch_0)
	branch_0 = Activation('relu', name='Block17_10_Branch_0_Conv2d_1x1_Activation')(branch_0)
	branch_1 = Conv2D(128, 1, strides=1, padding='same', use_bias=False, name= 'Block17_10_Branch_10_Conv2d_0a_1x1') (x)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_10_Branch_10_Conv2d_0a_1x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block17_10_Branch_10_Conv2d_0a_1x1_Activation')(branch_1)
	branch_1 = Conv2D(128, [1, 7], strides=1, padding='same', use_bias=False, name= 'Block17_10_Branch_10_Conv2d_0b_1x7') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_10_Branch_10_Conv2d_0b_1x7_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block17_10_Branch_10_Conv2d_0b_1x7_Activation')(branch_1)
	branch_1 = Conv2D(128, [7, 1], strides=1, padding='same', use_bias=False, name= 'Block17_10_Branch_10_Conv2d_0c_7x1') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block17_10_Branch_10_Conv2d_0c_7x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block17_10_Branch_10_Conv2d_0c_7x1_Activation')(branch_1)
	branches = [branch_0, branch_1]
	mixed = Concatenate(axis=3, name='Block17_10_Concatenate')(branches)
	up = Conv2D(896, 1, strides=1, padding='same', use_bias=True, name= 'Block17_10_Conv2d_1x1') (mixed)
	up = Lambda(scaling, output_shape=K.int_shape(up)[1:], arguments={'scale': 0.1})(up)
	x = add([x, up])
	x = Activation('relu', name='Block17_10_Activation')(x)

	# Mixed 7a (Reduction-B block): 8 x 8 x 2080	
	branch_0 = Conv2D(256, 1, strides=1, padding='same', use_bias=False, name= 'Mixed_7a_Branch_0_Conv2d_0a_1x1') (x)
	branch_0 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Mixed_7a_Branch_0_Conv2d_0a_1x1_BatchNorm')(branch_0)
	branch_0 = Activation('relu', name='Mixed_7a_Branch_0_Conv2d_0a_1x1_Activation')(branch_0)
	branch_0 = Conv2D(384, 3, strides=2, padding='valid', use_bias=False, name= 'Mixed_7a_Branch_0_Conv2d_1a_3x3') (branch_0)
	branch_0 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Mixed_7a_Branch_0_Conv2d_1a_3x3_BatchNorm')(branch_0)
	branch_0 = Activation('relu', name='Mixed_7a_Branch_0_Conv2d_1a_3x3_Activation')(branch_0)
	branch_1 = Conv2D(256, 1, strides=1, padding='same', use_bias=False, name= 'Mixed_7a_Branch_1_Conv2d_0a_1x1') (x)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Mixed_7a_Branch_1_Conv2d_0a_1x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Mixed_7a_Branch_1_Conv2d_0a_1x1_Activation')(branch_1)
	branch_1 = Conv2D(256, 3, strides=2, padding='valid', use_bias=False, name= 'Mixed_7a_Branch_1_Conv2d_1a_3x3') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Mixed_7a_Branch_1_Conv2d_1a_3x3_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Mixed_7a_Branch_1_Conv2d_1a_3x3_Activation')(branch_1)
	branch_2 = Conv2D(256, 1, strides=1, padding='same', use_bias=False, name= 'Mixed_7a_Branch_2_Conv2d_0a_1x1') (x)
	branch_2 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Mixed_7a_Branch_2_Conv2d_0a_1x1_BatchNorm')(branch_2)
	branch_2 = Activation('relu', name='Mixed_7a_Branch_2_Conv2d_0a_1x1_Activation')(branch_2)
	branch_2 = Conv2D(256, 3, strides=1, padding='same', use_bias=False, name= 'Mixed_7a_Branch_2_Conv2d_0b_3x3') (branch_2)
	branch_2 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Mixed_7a_Branch_2_Conv2d_0b_3x3_BatchNorm')(branch_2)
	branch_2 = Activation('relu', name='Mixed_7a_Branch_2_Conv2d_0b_3x3_Activation')(branch_2)
	branch_2 = Conv2D(256, 3, strides=2, padding='valid', use_bias=False, name= 'Mixed_7a_Branch_2_Conv2d_1a_3x3') (branch_2)
	branch_2 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Mixed_7a_Branch_2_Conv2d_1a_3x3_BatchNorm')(branch_2)
	branch_2 = Activation('relu', name='Mixed_7a_Branch_2_Conv2d_1a_3x3_Activation')(branch_2)
	branch_pool = MaxPooling2D(3, strides=2, padding='valid', name='Mixed_7a_Branch_3_MaxPool_1a_3x3')(x)
	branches = [branch_0, branch_1, branch_2, branch_pool]
	x = Concatenate(axis=3, name='Mixed_7a')(branches)

	# 5x Block8 (Inception-ResNet-C block):
	
	branch_0 = Conv2D(192, 1, strides=1, padding='same', use_bias=False, name= 'Block8_1_Branch_0_Conv2d_1x1') (x)
	branch_0 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block8_1_Branch_0_Conv2d_1x1_BatchNorm')(branch_0)
	branch_0 = Activation('relu', name='Block8_1_Branch_0_Conv2d_1x1_Activation')(branch_0)
	branch_1 = Conv2D(192, 1, strides=1, padding='same', use_bias=False, name= 'Block8_1_Branch_1_Conv2d_0a_1x1') (x)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block8_1_Branch_1_Conv2d_0a_1x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block8_1_Branch_1_Conv2d_0a_1x1_Activation')(branch_1)
	branch_1 = Conv2D(192, [1, 3], strides=1, padding='same', use_bias=False, name= 'Block8_1_Branch_1_Conv2d_0b_1x3') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block8_1_Branch_1_Conv2d_0b_1x3_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block8_1_Branch_1_Conv2d_0b_1x3_Activation')(branch_1)
	branch_1 = Conv2D(192, [3, 1], strides=1, padding='same', use_bias=False, name= 'Block8_1_Branch_1_Conv2d_0c_3x1') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block8_1_Branch_1_Conv2d_0c_3x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block8_1_Branch_1_Conv2d_0c_3x1_Activation')(branch_1)
	branches = [branch_0, branch_1]
	mixed = Concatenate(axis=3, name='Block8_1_Concatenate')(branches)
	up = Conv2D(1792, 1, strides=1, padding='same', use_bias=True, name= 'Block8_1_Conv2d_1x1') (mixed)
	up = Lambda(scaling, output_shape=K.int_shape(up)[1:], arguments={'scale': 0.2})(up)
	x = add([x, up])
	x = Activation('relu', name='Block8_1_Activation')(x)
	
	branch_0 = Conv2D(192, 1, strides=1, padding='same', use_bias=False, name= 'Block8_2_Branch_0_Conv2d_1x1') (x)
	branch_0 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block8_2_Branch_0_Conv2d_1x1_BatchNorm')(branch_0)
	branch_0 = Activation('relu', name='Block8_2_Branch_0_Conv2d_1x1_Activation')(branch_0)
	branch_1 = Conv2D(192, 1, strides=1, padding='same', use_bias=False, name= 'Block8_2_Branch_2_Conv2d_0a_1x1') (x)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block8_2_Branch_2_Conv2d_0a_1x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block8_2_Branch_2_Conv2d_0a_1x1_Activation')(branch_1)
	branch_1 = Conv2D(192, [1, 3], strides=1, padding='same', use_bias=False, name= 'Block8_2_Branch_2_Conv2d_0b_1x3') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block8_2_Branch_2_Conv2d_0b_1x3_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block8_2_Branch_2_Conv2d_0b_1x3_Activation')(branch_1)
	branch_1 = Conv2D(192, [3, 1], strides=1, padding='same', use_bias=False, name= 'Block8_2_Branch_2_Conv2d_0c_3x1') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block8_2_Branch_2_Conv2d_0c_3x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block8_2_Branch_2_Conv2d_0c_3x1_Activation')(branch_1)
	branches = [branch_0, branch_1]
	mixed = Concatenate(axis=3, name='Block8_2_Concatenate')(branches)
	up = Conv2D(1792, 1, strides=1, padding='same', use_bias=True, name= 'Block8_2_Conv2d_1x1') (mixed)
	up = Lambda(scaling, output_shape=K.int_shape(up)[1:], arguments={'scale': 0.2})(up)
	x = add([x, up])
	x = Activation('relu', name='Block8_2_Activation')(x)
	
	branch_0 = Conv2D(192, 1, strides=1, padding='same', use_bias=False, name= 'Block8_3_Branch_0_Conv2d_1x1') (x)
	branch_0 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block8_3_Branch_0_Conv2d_1x1_BatchNorm')(branch_0)
	branch_0 = Activation('relu', name='Block8_3_Branch_0_Conv2d_1x1_Activation')(branch_0)
	branch_1 = Conv2D(192, 1, strides=1, padding='same', use_bias=False, name= 'Block8_3_Branch_3_Conv2d_0a_1x1') (x)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block8_3_Branch_3_Conv2d_0a_1x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block8_3_Branch_3_Conv2d_0a_1x1_Activation')(branch_1)
	branch_1 = Conv2D(192, [1, 3], strides=1, padding='same', use_bias=False, name= 'Block8_3_Branch_3_Conv2d_0b_1x3') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block8_3_Branch_3_Conv2d_0b_1x3_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block8_3_Branch_3_Conv2d_0b_1x3_Activation')(branch_1)
	branch_1 = Conv2D(192, [3, 1], strides=1, padding='same', use_bias=False, name= 'Block8_3_Branch_3_Conv2d_0c_3x1') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block8_3_Branch_3_Conv2d_0c_3x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block8_3_Branch_3_Conv2d_0c_3x1_Activation')(branch_1)
	branches = [branch_0, branch_1]
	mixed = Concatenate(axis=3, name='Block8_3_Concatenate')(branches)
	up = Conv2D(1792, 1, strides=1, padding='same', use_bias=True, name= 'Block8_3_Conv2d_1x1') (mixed)
	up = Lambda(scaling, output_shape=K.int_shape(up)[1:], arguments={'scale': 0.2})(up)
	x = add([x, up])
	x = Activation('relu', name='Block8_3_Activation')(x)
	
	branch_0 = Conv2D(192, 1, strides=1, padding='same', use_bias=False, name= 'Block8_4_Branch_0_Conv2d_1x1') (x)
	branch_0 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block8_4_Branch_0_Conv2d_1x1_BatchNorm')(branch_0)
	branch_0 = Activation('relu', name='Block8_4_Branch_0_Conv2d_1x1_Activation')(branch_0)
	branch_1 = Conv2D(192, 1, strides=1, padding='same', use_bias=False, name= 'Block8_4_Branch_4_Conv2d_0a_1x1') (x)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block8_4_Branch_4_Conv2d_0a_1x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block8_4_Branch_4_Conv2d_0a_1x1_Activation')(branch_1)
	branch_1 = Conv2D(192, [1, 3], strides=1, padding='same', use_bias=False, name= 'Block8_4_Branch_4_Conv2d_0b_1x3') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block8_4_Branch_4_Conv2d_0b_1x3_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block8_4_Branch_4_Conv2d_0b_1x3_Activation')(branch_1)
	branch_1 = Conv2D(192, [3, 1], strides=1, padding='same', use_bias=False, name= 'Block8_4_Branch_4_Conv2d_0c_3x1') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block8_4_Branch_4_Conv2d_0c_3x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block8_4_Branch_4_Conv2d_0c_3x1_Activation')(branch_1)
	branches = [branch_0, branch_1]
	mixed = Concatenate(axis=3, name='Block8_4_Concatenate')(branches)
	up = Conv2D(1792, 1, strides=1, padding='same', use_bias=True, name= 'Block8_4_Conv2d_1x1') (mixed)
	up = Lambda(scaling, output_shape=K.int_shape(up)[1:], arguments={'scale': 0.2})(up)
	x = add([x, up])
	x = Activation('relu', name='Block8_4_Activation')(x)
	
	branch_0 = Conv2D(192, 1, strides=1, padding='same', use_bias=False, name= 'Block8_5_Branch_0_Conv2d_1x1') (x)
	branch_0 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block8_5_Branch_0_Conv2d_1x1_BatchNorm')(branch_0)
	branch_0 = Activation('relu', name='Block8_5_Branch_0_Conv2d_1x1_Activation')(branch_0)
	branch_1 = Conv2D(192, 1, strides=1, padding='same', use_bias=False, name= 'Block8_5_Branch_5_Conv2d_0a_1x1') (x)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block8_5_Branch_5_Conv2d_0a_1x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block8_5_Branch_5_Conv2d_0a_1x1_Activation')(branch_1)
	branch_1 = Conv2D(192, [1, 3], strides=1, padding='same', use_bias=False, name= 'Block8_5_Branch_5_Conv2d_0b_1x3') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block8_5_Branch_5_Conv2d_0b_1x3_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block8_5_Branch_5_Conv2d_0b_1x3_Activation')(branch_1)
	branch_1 = Conv2D(192, [3, 1], strides=1, padding='same', use_bias=False, name= 'Block8_5_Branch_5_Conv2d_0c_3x1') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block8_5_Branch_5_Conv2d_0c_3x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block8_5_Branch_5_Conv2d_0c_3x1_Activation')(branch_1)
	branches = [branch_0, branch_1]
	mixed = Concatenate(axis=3, name='Block8_5_Concatenate')(branches)
	up = Conv2D(1792, 1, strides=1, padding='same', use_bias=True, name= 'Block8_5_Conv2d_1x1') (mixed)
	up = Lambda(scaling, output_shape=K.int_shape(up)[1:], arguments={'scale': 0.2})(up)
	x = add([x, up])
	x = Activation('relu', name='Block8_5_Activation')(x)
	
	branch_0 = Conv2D(192, 1, strides=1, padding='same', use_bias=False, name= 'Block8_6_Branch_0_Conv2d_1x1') (x)
	branch_0 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block8_6_Branch_0_Conv2d_1x1_BatchNorm')(branch_0)
	branch_0 = Activation('relu', name='Block8_6_Branch_0_Conv2d_1x1_Activation')(branch_0)
	branch_1 = Conv2D(192, 1, strides=1, padding='same', use_bias=False, name= 'Block8_6_Branch_1_Conv2d_0a_1x1') (x)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block8_6_Branch_1_Conv2d_0a_1x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block8_6_Branch_1_Conv2d_0a_1x1_Activation')(branch_1)
	branch_1 = Conv2D(192, [1, 3], strides=1, padding='same', use_bias=False, name= 'Block8_6_Branch_1_Conv2d_0b_1x3') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block8_6_Branch_1_Conv2d_0b_1x3_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block8_6_Branch_1_Conv2d_0b_1x3_Activation')(branch_1)
	branch_1 = Conv2D(192, [3, 1], strides=1, padding='same', use_bias=False, name= 'Block8_6_Branch_1_Conv2d_0c_3x1') (branch_1)
	branch_1 = BatchNormalization(axis=3, momentum=0.995, epsilon=0.001, scale=False, name='Block8_6_Branch_1_Conv2d_0c_3x1_BatchNorm')(branch_1)
	branch_1 = Activation('relu', name='Block8_6_Branch_1_Conv2d_0c_3x1_Activation')(branch_1)
	branches = [branch_0, branch_1]
	mixed = Concatenate(axis=3, name='Block8_6_Concatenate')(branches)
	up = Conv2D(1792, 1, strides=1, padding='same', use_bias=True, name= 'Block8_6_Conv2d_1x1') (mixed)
	up = Lambda(scaling, output_shape=K.int_shape(up)[1:], arguments={'scale': 1})(up)
	x = add([x, up])
	
	# Classification block
	x = GlobalAveragePooling2D(name='AvgPool')(x)
	x = Dropout(1.0 - 0.8, name='Dropout')(x)
	# Bottleneck
	x = Dense(128, use_bias=False, name='Bottleneck')(x)
	x = BatchNormalization(momentum=0.995, epsilon=0.001, scale=False, name='Bottleneck_BatchNorm')(x)

	# Create model
	model = Model(inputs, x, name='inception_resnet_v1')

	return model

def loadModel():
	model = InceptionResNetV2()
	
	model.load_weights('/content/content/models/facenet_weights.h5')
	
	#-----------------------------------
	
	return model

# %%
# !gdown https://drive.google.com/a/gla.ac.in/uc?id=1JBYpzdIHRl8u0z4MuM3jDKqrTWRYbjqo&export=download
# Out:
# Downloading...
# From: https://drive.google.com/a/gla.ac.in/uc?id=1JBYpzdIHRl8u0z4MuM3jDKqrTWRYbjqo
# To: /content/attendance.zip
# 214MB [00:01, 118MB/s]

# %%
# !unzip /content/attendance.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: attendance/Fernando_Henrique_Cardoso/Fernando_Henrique_Cardoso_0001.jpg
#   inflating: __MACOSX/attendance/Fernando_Henrique_Cardoso/._Fernando_Henrique_Cardoso_0001.jpg
#   inflating: __MACOSX/attendance/._Fernando_Henrique_Cardoso
#    creating: attendance/Ricardo_Sanchez/
#   inflating: attendance/Ricardo_Sanchez/Ricardo_Sanchez_0006.jpg
#    creating: __MACOSX/attendance/Ricardo_Sanchez/
#   inflating: __MACOSX/attendance/Ricardo_Sanchez/._Ricardo_Sanchez_0006.jpg
#   inflating: attendance/Ricardo_Sanchez/Ricardo_Sanchez_0004.jpg
#   inflating: __MACOSX/attendance/Ricardo_Sanchez/._Ricardo_Sanchez_0004.jpg
#   inflating: attendance/Ricardo_Sanchez/Ricardo_Sanchez_0005.jpg
#   inflating: __MACOSX/attendance/Ricardo_Sanchez/._Ricardo_Sanchez_0005.jpg
#   inflating: attendance/Ricardo_Sanchez/Ricardo_Sanchez_0001.jpg
#   inflating: __MACOSX/attendance/Ricardo_Sanchez/._Ricardo_Sanchez_0001.jpg
#   inflating: attendance/Ricardo_Sanchez/Ricardo_Sanchez_0002.jpg
#   inflating: __MACOSX/attendance/Ricardo_Sanchez/._Ricardo_Sanchez_0002.jpg
#   inflating: attendance/Ricardo_Sanchez/Ricardo_Sanchez_0003.jpg
#   inflating: __MACOSX/attendance/Ricardo_Sanchez/._Ricardo_Sanchez_0003.jpg
#   inflating: __MACOSX/attendance/._Ricardo_Sanchez
#    creating: attendance/Joe_Nichols/
#   inflating: attendance/Joe_Nichols/Joe_Nichols_0001.jpg
#    creating: __MACOSX/attendance/Joe_Nichols/
#   inflating: __MACOSX/attendance/Joe_Nichols/._Joe_Nichols_0001.jpg
#   inflating: attendance/Joe_Nichols/Joe_Nichols_0002.jpg
#   inflating: __MACOSX/attendance/Joe_Nichols/._Joe_Nichols_0002.jpg
#   inflating: attendance/Joe_Nichols/Joe_Nichols_0003.jpg
#   inflating: __MACOSX/attendance/Joe_Nichols/._Joe_Nichols_0003.jpg
#   inflating: attendance/Joe_Nichols/Joe_Nichols_0004.jpg
#   inflating: __MACOSX/attendance/Joe_Nichols/._Joe_Nichols_0004.jpg
#   inflating: __MACOSX/attendance/._Joe_Nichols
#    creating: attendance/Sean_Patrick_OMalley/
#   inflating: attendance/Sean_Patrick_OMalley/Sean_Patrick_OMalley_0001.jpg
#    creating: __MACOSX/attendance/Sean_Patrick_OMalley/
#   inflating: __MACOSX/attendance/Sean_Patrick_OMalley/._Sean_Patrick_OMalley_0001.jpg
#   inflating: attendance/Sean_Patrick_OMalley/Sean_Patrick_OMalley_0002.jpg
#   inflating: __MACOSX/attendance/Sean_Patrick_OMalley/._Sean_Patrick_OMalley_0002.jpg
#   inflating: attendance/Sean_Patrick_OMalley/Sean_Patrick_OMalley_0003.jpg
#   inflating: __MACOSX/attendance/Sean_Patrick_OMalley/._Sean_Patrick_OMalley_0003.jpg
#   inflating: __MACOSX/attendance/._Sean_Patrick_OMalley
#    creating: attendance/Bill_Paxton/
#   inflating: attendance/Bill_Paxton/Bill_Paxton_0002.jpg
#    creating: __MACOSX/attendance/Bill_Paxton/
#   inflating: __MACOSX/attendance/Bill_Paxton/._Bill_Paxton_0002.jpg
#   inflating: attendance/Bill_Paxton/Bill_Paxton_0003.jpg
#   inflating: __MACOSX/attendance/Bill_Paxton/._Bill_Paxton_0003.jpg
#   inflating: attendance/Bill_Paxton/Bill_Paxton_0001.jpg
#   inflating: __MACOSX/attendance/Bill_Paxton/._Bill_Paxton_0001.jpg
#   inflating: attendance/Bill_Paxton/Bill_Paxton_0004.jpg
#   inflating: __MACOSX/attendance/Bill_Paxton/._Bill_Paxton_0004.jpg
#   inflating: __MACOSX/attendance/._Bill_Paxton
#    creating: attendance/Junichiro_Koizumi/
#   inflating: attendance/Junichiro_Koizumi/Junichiro_Koizumi_0045.jpg
#    creating: __MACOSX/attendance/Junichiro_Koizumi/
#   inflating: __MACOSX/attendance/Junichiro_Koizumi/._Junichiro_Koizumi_0045.jpg
#   inflating: attendance/Junichiro_Koizumi/Junichiro_Koizumi_0051.jpg
#   inflating: __MACOSX/attendance/Junichiro_Koizumi/._Junichiro_Koizumi_0051.jpg
#   inflating: attendance/Junichiro_Koizumi/Junichiro_Koizumi_0050.jpg
#   inflating: __MACOSX/attendance/Junichiro_Koizumi/._Junichiro_Koizumi_0050.jpg
#   inflating: attendance/Junichiro_Koizumi/Junichiro_Koizumi_0044.jpg
#   inflating: __MACOSX/attendance/Junichiro_Koizumi/._Junichiro_Koizumi_0044.jpg
#   inflating: attendance/Junichiro_Koizumi/Junichiro_Koizumi_0052.jpg
#   inflating: __MACOSX/attendance/Junichiro_Koizumi/._Junichiro_Koizumi_0052.jpg
#   inflating: attendance/Junichiro_Koizumi/Junichiro_Koizumi_0046.jpg
#   inflating: __MACOSX/attendance/Junichiro_Koizumi/._Junichiro_Koizumi_0046.jpg
#   inflating: attendance/Junichiro_Koizumi/Junichiro_Koizumi_0047.jpg
#   inflating: __MACOSX/attendance/Junichiro_Koizumi/._Junichiro_Koizumi_0047.jpg
#   inflating: attendance/Junichiro_Koizumi/Junichiro_Koizumi_0053.jpg
#   inflating: __MACOSX/attendance/Junichiro_Koizumi/._Junichiro_Koizumi_0053.jpg
#   inflating: attendance/Junichiro_Koizumi/Junichiro_Koizumi_0057.jpg
#   inflating: __MACOSX/attendance/Junichiro_Koizumi/._Junichiro_Koizumi_0057.jpg
#   inflating: attendance/Junichiro_Koizumi/Junichiro_Koizumi_0043.jpg
#   inflating: __MACOSX/attendance/Junichiro_Koizumi/._Junichiro_Koizumi_0043.jpg
#   inflating: attendance/Junichiro_Koizumi/Junichiro_Koizumi_0042.jpg
#   inflating: __MACOSX/attendance/Junichiro_Koizumi/._Junichiro_Koizumi_0042.jpg
#   inflating: attendance/Junichiro_Koizumi/Junichiro_Koizumi_0056.jpg
#   inflating: __MACOSX/attendance/Junichiro_Koizumi/._Junichiro_Koizumi_0056.jpg
#   inflating: attendance/Junichiro_Koizumi/Junichiro_Koizumi_0040.jpg
#   inflating: __MACOSX/attendance/Junichiro_Koizumi/._Junichiro_Koizumi_0040.jpg
#   inflating: attendance/Junichiro_Koizumi/Junichiro_Koizumi_0054.jpg
#   inflating: __MACOSX/attendance/Junichiro_Koizumi/._Junichiro_Koizumi_0054.jpg
#   inflating: attendance/Junichiro_Koizumi/Junichiro_Koizumi_0055.jpg
#   inflating: __MACOSX/attendance/Junichiro_Koizumi/._Junichiro_Koizumi_0055.jpg
#   inflating: attendance/Junichiro_Koizumi/Junichiro_Koizumi_0041.jpg
#   inflating: __MACOSX/attendance/Junichiro_Koizumi/._Junichiro_Koizumi_0041.jpg
#   inflating: attendance/Junichiro_Koizumi/Junichiro_Koizumi_0026.jpg
#   inflating: __MACOSX/attendance/Junichiro_Koizumi/._Junichiro_Koizumi_0026.jpg
#   inflating: attendance/Junichiro_Koizumi/Junichiro_Koizumi_0032.jpg
#   inflating: __MACOSX/attendance/Junichiro_Koizumi/._Junichiro_Koizumi_0032.jpg
#   inflating: attendance/Junichiro_Koizumi/Junichiro_Koizumi_0033.jpg
#   inflating: __MACOSX/attendance/Junichiro_Koizumi/._Junichiro_Koizumi_0033.jpg
#   inflating: attendance/Junichiro_Koizumi/Junichiro_Koizumi_0027.jpg
#   inflating: __MACOSX/attendance/Junichiro_Koizumi/._Junichiro_Koizumi_0027.jpg
#   inflating: attendance/Junichiro_Koizumi/Junichiro_Koizumi_0031.jpg
#   inflating: __MACOSX/attendance/Junichiro_Koizumi/._Junichiro_Koizumi_0031.jpg
#   inflating: attendance/Junichiro_Koizumi/Junichiro_Koizumi_0025.jpg
#   inflating: __MACOSX/attendance/Junichiro_Koizumi/._Junichiro_Koizumi_0025.jpg
#   inflating: attendance/Junichiro_Koizumi/Junichiro_Koizumi_0019.jpg
#   inflating: __MACOSX/attendance/Junichiro_Koizumi/._Junichiro_Koizumi_0019.jpg
#   inflating: attendance/Junichiro_Koizumi/Junichiro_Koizumi_0018.jpg
#   inflating: __MACOSX/attendance/Junichiro_Koizumi/._Junichiro_Koizumi_0018.jpg
#   inflating: attendance/Junichiro_Koizumi/Junichiro_Koizumi_0024.jpg
#   inflating: __MACOSX/attendance/Junichiro_Koizumi/._Junichiro_Koizumi_0024.jpg
#   inflating: attendance/Junichiro_Koizumi/Junichiro_Koizumi_0030.jpg
#   inflating: __MACOSX/attendance/Junichiro_Koizumi/._Junichiro_Koizumi_0030.jpg
#   inflating: attendance/Junichiro_Koizumi/Junichiro_Koizumi_0008.jpg
#   inflating: __MACOSX/attendance/Junichiro_Koizumi/._Junichiro_Koizumi_0008.jpg
#   inflating: attendance/Junichiro_Koizumi/Junichiro_Koizumi_0034.jpg
#   inflating: __MACOSX/attendance/Junichiro_Koizumi/._Junichiro_Koizumi_0034.jpg
#   inflating: attendance/Junichiro_Koizumi/Junichiro_Koizumi_0020.jpg
#   inflating: __MACOSX/attendance/Junichiro_Koizumi/._Junichiro_Koizumi_0020.jpg
#   inflating: attendance/Junichiro_Koizumi/Junichiro_Koizumi_0021.jpg
#   inflating: __MACOSX/attendance/Junichiro_Koizumi/._Junichiro_Koizumi_0021.jpg
#   inflating: attendance/Junichiro_Koizumi/Junichiro_Koizumi_0035.jpg
#   inflating: __MACOSX/attendance/Junichiro_Koizumi/._Junichiro_Koizumi_0035.jpg
#   inflating: attendance/Junichiro_Koizumi/Junichiro_Koizumi_0009.jpg
#   inflating: __MACOSX/attendance/Junichiro_Koizumi/._Junichiro_Koizumi_0009.jpg
#   inflating: attendance/Junichiro_Koizumi/Junichiro_Koizumi_0023.jpg
#   inflating: __MACOSX/attendance/Junichiro_Koizumi/._Junichiro_Koizumi_0023.jpg
#   inflating: attendance/Junichiro_Koizumi/Junichiro_Koizumi_0037.jpg
#   inflating: __MACOSX/attendance/Junichiro_Koizumi/._Junichiro_Koizumi_0037.jpg
#   inflating: attendance/Junichiro_Koizumi/Junichiro_Koizumi_0036.jpg
#   inflating: __MACOSX/attendance/Junichiro_Koizumi/._Junichiro_Koizumi_0036.jpg
#   inflating: attendance/Junichiro_Koizumi/Junichiro_Koizumi_0022.jpg
#   inflating: __MACOSX/attendance/Junichiro_Koizumi/._Junichiro_Koizumi_0022.jpg
#   inflating: attendance/Junichiro_Koizumi/Junichiro_Koizumi_0007.jpg
#   inflating: __MACOSX/attendance/Junichiro_Koizumi/._Junichiro_Koizumi_0007.jpg
#   inflating: attendance/Junichiro_Koizumi/Junichiro_Koizumi_0013.jpg
#   inflating: __MACOSX/attendance/Junichiro_Koizumi/._Junichiro_Koizumi_0013.jpg
#   inflating: attendance/Junichiro_Koizumi/Junichiro_Koizumi_0012.jpg
#   inflating: __MACOSX/attendance/Junichiro_Koizumi/._Junichiro_Koizumi_0012.jpg
#   inflating: attendance/Junichiro_Koizumi/Junichiro_Koizumi_0006.jpg
#   inflating: __MACOSX/attendance/Junichiro_Koizumi/._Junichiro_Koizumi_0006.jpg
#   inflating: attendance/Junichiro_Koizumi/Junichiro_Koizumi_0010.jpg
#   inflating: __MACOSX/attendance/Junichiro_Koizumi/._Junichiro_Koizumi_0010.jpg
#   inflating: attendance/Junichiro_Koizumi/Junichiro_Koizumi_0004.jpg
#   inflating: __MACOSX/attendance/Junichiro_Koizumi/._Junichiro_Koizumi_0004.jpg
#   inflating: attendance/Junichiro_Koizumi/Junichiro_Koizumi_0038.jpg
#   inflating: __MACOSX/attendance/Junichiro_Koizumi/._Junichiro_Koizumi_0038.jpg
#   inflating: attendance/Junichiro_Koizumi/Junichiro_Koizumi_0039.jpg
#   inflating: __MACOSX/attendance/Junichiro_Koizumi/._Junichiro_Koizumi_0039.jpg
#   inflating: attendance/Junichiro_Koizumi/Junichiro_Koizumi_0005.jpg
#   inflating: __MACOSX/attendance/Junichiro_Koizumi/._Junichiro_Koizumi_0005.jpg
#   inflating: attendance/Junichiro_Koizumi/Junichiro_Koizumi_0011.jpg
#   inflating: __MACOSX/attendance/Junichiro_Koizumi/._Junichiro_Koizumi_0011.jpg
#   inflating: attendance/Junichiro_Koizumi/Junichiro_Koizumi_0029.jpg
#   inflating: __MACOSX/attendance/Junichiro_Koizumi/._Junichiro_Koizumi_0029.jpg
#   inflating: attendance/Junichiro_Koizumi/Junichiro_Koizumi_0015.jpg
#   inflating: __MACOSX/attendance/Junichiro_Koizumi/._Junichiro_Koizumi_0015.jpg
#   inflating: attendance/Junichiro_Koizumi/Junichiro_Koizumi_0001.jpg
#   inflating: __MACOSX/attendance/Junichiro_Koizumi/._Junichiro_Koizumi_0001.jpg
#   inflating: attendance/Junichiro_Koizumi/Junichiro_Koizumi_0014.jpg
#   inflating: __MACOSX/attendance/Junichiro_Koizumi/._Junichiro_Koizumi_0014.jpg
#   inflating: attendance/Junichiro_Koizumi/Junichiro_Koizumi_0028.jpg
#   inflating: __MACOSX/attendance/Junichiro_Koizumi/._Junichiro_Koizumi_0028.jpg
#   inflating: attendance/Junichiro_Koizumi/Junichiro_Koizumi_0002.jpg
#   inflating: __MACOSX/attendance/Junichiro_Koizumi/._Junichiro_Koizumi_0002.jpg
#   inflating: attendance/Junichiro_Koizumi/Junichiro_Koizumi_0016.jpg
#   inflating: __MACOSX/attendance/Junichiro_Koizumi/._Junichiro_Koizumi_0016.jpg
#   inflating: attendance/Junichiro_Koizumi/Junichiro_Koizumi_0017.jpg
#   inflating: __MACOSX/attendance/Junichiro_Koizumi/._Junichiro_Koizumi_0017.jpg
#   inflating: attendance/Junichiro_Koizumi/Junichiro_Koizumi_0003.jpg
#   inflating: __MACOSX/attendance/Junichiro_Koizumi/._Junichiro_Koizumi_0003.jpg
#   inflating: attendance/Junichiro_Koizumi/Junichiro_Koizumi_0058.jpg
#   inflating: __MACOSX/attendance/Junichiro_Koizumi/._Junichiro_Koizumi_0058.jpg
#   inflating: attendance/Junichiro_Koizumi/Junichiro_Koizumi_0059.jpg
#   inflating: __MACOSX/attendance/Junichiro_Koizumi/._Junichiro_Koizumi_0059.jpg
#   inflating: attendance/Junichiro_Koizumi/Junichiro_Koizumi_0049.jpg
#   inflating: __MACOSX/attendance/Junichiro_Koizumi/._Junichiro_Koizumi_0049.jpg
#   inflating: attendance/Junichiro_Koizumi/Junichiro_Koizumi_0060.jpg
#   inflating: __MACOSX/attendance/Junichiro_Koizumi/._Junichiro_Koizumi_0060.jpg
#   inflating: attendance/Junichiro_Koizumi/Junichiro_Koizumi_0048.jpg
#   inflating: __MACOSX/attendance/Junichiro_Koizumi/._Junichiro_Koizumi_0048.jpg
#   inflating: __MACOSX/attendance/._Junichiro_Koizumi
#    creating: attendance/Allyson_Felix/
#   inflating: attendance/Allyson_Felix/Allyson_Felix_0001.jpg
#    creating: __MACOSX/attendance/Allyson_Felix/
#   inflating: __MACOSX/attendance/Allyson_Felix/._Allyson_Felix_0001.jpg
#   inflating: attendance/Allyson_Felix/Allyson_Felix_0002.jpg
#   inflating: __MACOSX/attendance/Allyson_Felix/._Allyson_Felix_0002.jpg
#   inflating: attendance/Allyson_Felix/Allyson_Felix_0003.jpg
#   inflating: __MACOSX/attendance/Allyson_Felix/._Allyson_Felix_0003.jpg
#   inflating: attendance/Allyson_Felix/Allyson_Felix_0004.jpg
#   inflating: __MACOSX/attendance/Allyson_Felix/._Allyson_Felix_0004.jpg
#   inflating: attendance/Allyson_Felix/Allyson_Felix_0005.jpg
#   inflating: __MACOSX/attendance/Allyson_Felix/._Allyson_Felix_0005.jpg
#   inflating: __MACOSX/attendance/._Allyson_Felix
#    creating: attendance/Rick_Barnes/
#   inflating: attendance/Rick_Barnes/Rick_Barnes_0003.jpg
#    creating: __MACOSX/attendance/Rick_Barnes/
#   inflating: __MACOSX/attendance/Rick_Barnes/._Rick_Barnes_0003.jpg
#   inflating: attendance/Rick_Barnes/Rick_Barnes_0002.jpg
#   inflating: __MACOSX/attendance/Rick_Barnes/._Rick_Barnes_0002.jpg
#   inflating: attendance/Rick_Barnes/Rick_Barnes_0001.jpg
#   inflating: __MACOSX/attendance/Rick_Barnes/._Rick_Barnes_0001.jpg
#   inflating: __MACOSX/attendance/._Rick_Barnes
#    creating: attendance/Franz_Fischler/
#   inflating: attendance/Franz_Fischler/Franz_Fischler_0004.jpg
#    creating: __MACOSX/attendance/Franz_Fischler/
#   inflating: __MACOSX/attendance/Franz_Fischler/._Franz_Fischler_0004.jpg
#   inflating: attendance/Franz_Fischler/Franz_Fischler_0001.jpg
#   inflating: __MACOSX/attendance/Franz_Fischler/._Franz_Fischler_0001.jpg
#   inflating: attendance/Franz_Fischler/Franz_Fischler_0003.jpg
#   inflating: __MACOSX/attendance/Franz_Fischler/._Franz_Fischler_0003.jpg
#   inflating: attendance/Franz_Fischler/Franz_Fischler_0002.jpg
#   inflating: __MACOSX/attendance/Franz_Fischler/._Franz_Fischler_0002.jpg
#   inflating: __MACOSX/attendance/._Franz_Fischler
#    creating: attendance/Ian_McKellen/
#   inflating: attendance/Ian_McKellen/Ian_McKellen_0001.jpg
#    creating: __MACOSX/attendance/Ian_McKellen/
#   inflating: __MACOSX/attendance/Ian_McKellen/._Ian_McKellen_0001.jpg
#   inflating: attendance/Ian_McKellen/Ian_McKellen_0002.jpg
#   inflating: __MACOSX/attendance/Ian_McKellen/._Ian_McKellen_0002.jpg
#   inflating: attendance/Ian_McKellen/Ian_McKellen_0003.jpg
#   inflating: __MACOSX/attendance/Ian_McKellen/._Ian_McKellen_0003.jpg
#   inflating: __MACOSX/attendance/._Ian_McKellen
#    creating: attendance/Kenneth_Bowersox/
#   inflating: attendance/Kenneth_Bowersox/Kenneth_Bowersox_0003.jpg
#    creating: __MACOSX/attendance/Kenneth_Bowersox/
#   inflating: __MACOSX/attendance/Kenneth_Bowersox/._Kenneth_Bowersox_0003.jpg
#   inflating: attendance/Kenneth_Bowersox/Kenneth_Bowersox_0002.jpg
#   inflating: __MACOSX/attendance/Kenneth_Bowersox/._Kenneth_Bowersox_0002.jpg
#   inflating: attendance/Kenneth_Bowersox/Kenneth_Bowersox_0001.jpg
#   inflating: __MACOSX/attendance/Kenneth_Bowersox/._Kenneth_Bowersox_0001.jpg
#   inflating: __MACOSX/attendance/._Kenneth_Bowersox
#    creating: attendance/Natasha_McElhone/
#   inflating: attendance/Natasha_McElhone/Natasha_McElhone_0001.jpg
#    creating: __MACOSX/attendance/Natasha_McElhone/
#   inflating: __MACOSX/attendance/Natasha_McElhone/._Natasha_McElhone_0001.jpg
#   inflating: attendance/Natasha_McElhone/Natasha_McElhone_0002.jpg
#   inflating: __MACOSX/attendance/Natasha_McElhone/._Natasha_McElhone_0002.jpg
#   inflating: attendance/Natasha_McElhone/Natasha_McElhone_0003.jpg
#   inflating: __MACOSX/attendance/Natasha_McElhone/._Natasha_McElhone_0003.jpg
#   inflating: __MACOSX/attendance/._Natasha_McElhone
#    creating: attendance/Antony_Leung/
#   inflating: attendance/Antony_Leung/Antony_Leung_0003.jpg
#    creating: __MACOSX/attendance/Antony_Leung/
#   inflating: __MACOSX/attendance/Antony_Leung/._Antony_Leung_0003.jpg
#   inflating: attendance/Antony_Leung/Antony_Leung_0002.jpg
#   inflating: __MACOSX/attendance/Antony_Leung/._Antony_Leung_0002.jpg
#   inflating: attendance/Antony_Leung/Antony_Leung_0001.jpg
#   inflating: __MACOSX/attendance/Antony_Leung/._Antony_Leung_0001.jpg
#   inflating: attendance/Antony_Leung/Antony_Leung_0004.jpg
#   inflating: __MACOSX/attendance/Antony_Leung/._Antony_Leung_0004.jpg
#   inflating: __MACOSX/attendance/._Antony_Leung
#    creating: attendance/Natalie_Maines/
#   inflating: attendance/Natalie_Maines/Natalie_Maines_0004.jpg
#    creating: __MACOSX/attendance/Natalie_Maines/
#   inflating: __MACOSX/attendance/Natalie_Maines/._Natalie_Maines_0004.jpg
#   inflating: attendance/Natalie_Maines/Natalie_Maines_0005.jpg
#   inflating: __MACOSX/attendance/Natalie_Maines/._Natalie_Maines_0005.jpg
#   inflating: attendance/Natalie_Maines/Natalie_Maines_0001.jpg
#   inflating: __MACOSX/attendance/Natalie_Maines/._Natalie_Maines_0001.jpg
#   inflating: attendance/Natalie_Maines/Natalie_Maines_0002.jpg
#   inflating: __MACOSX/attendance/Natalie_Maines/._Natalie_Maines_0002.jpg
#   inflating: attendance/Natalie_Maines/Natalie_Maines_0003.jpg
#   inflating: __MACOSX/attendance/Natalie_Maines/._Natalie_Maines_0003.jpg
#   inflating: __MACOSX/attendance/._Natalie_Maines
#    creating: attendance/Warren_Buffett/
#   inflating: attendance/Warren_Buffett/Warren_Buffett_0002.jpg
#    creating: __MACOSX/attendance/Warren_Buffett/
#   inflating: __MACOSX/attendance/Warren_Buffett/._Warren_Buffett_0002.jpg
#   inflating: attendance/Warren_Buffett/Warren_Buffett_0003.jpg
#   inflating: __MACOSX/attendance/Warren_Buffett/._Warren_Buffett_0003.jpg
#   inflating: attendance/Warren_Buffett/Warren_Buffett_0001.jpg
#   inflating: __MACOSX/attendance/Warren_Buffett/._Warren_Buffett_0001.jpg
#   inflating: __MACOSX/attendance/._Warren_Buffett
#    creating: attendance/Mark_Wahlberg/
#   inflating: attendance/Mark_Wahlberg/Mark_Wahlberg_0004.jpg
#    creating: __MACOSX/attendance/Mark_Wahlberg/
#   inflating: __MACOSX/attendance/Mark_Wahlberg/._Mark_Wahlberg_0004.jpg
#   inflating: attendance/Mark_Wahlberg/Mark_Wahlberg_0003.jpg
#   inflating: __MACOSX/attendance/Mark_Wahlberg/._Mark_Wahlberg_0003.jpg
#   inflating: attendance/Mark_Wahlberg/Mark_Wahlberg_0002.jpg
#   inflating: __MACOSX/attendance/Mark_Wahlberg/._Mark_Wahlberg_0002.jpg
#   inflating: attendance/Mark_Wahlberg/Mark_Wahlberg_0001.jpg
#   inflating: __MACOSX/attendance/Mark_Wahlberg/._Mark_Wahlberg_0001.jpg
#   inflating: __MACOSX/attendance/._Mark_Wahlberg
#    creating: attendance/Bill_Graham/
#   inflating: attendance/Bill_Graham/Bill_Graham_0009.jpg
#    creating: __MACOSX/attendance/Bill_Graham/
#   inflating: __MACOSX/attendance/Bill_Graham/._Bill_Graham_0009.jpg
#   inflating: attendance/Bill_Graham/Bill_Graham_0008.jpg
#   inflating: __MACOSX/attendance/Bill_Graham/._Bill_Graham_0008.jpg
#   inflating: attendance/Bill_Graham/Bill_Graham_0005.jpg
#   inflating: __MACOSX/attendance/Bill_Graham/._Bill_Graham_0005.jpg
#   inflating: attendance/Bill_Graham/Bill_Graham_0004.jpg
#   inflating: __MACOSX/attendance/Bill_Graham/._Bill_Graham_0004.jpg
#   inflating: attendance/Bill_Graham/Bill_Graham_0006.jpg
#   inflating: __MACOSX/attendance/Bill_Graham/._Bill_Graham_0006.jpg
#   inflating: attendance/Bill_Graham/Bill_Graham_0007.jpg
#   inflating: __MACOSX/attendance/Bill_Graham/._Bill_Graham_0007.jpg
#   inflating: attendance/Bill_Graham/Bill_Graham_0003.jpg
#   inflating: __MACOSX/attendance/Bill_Graham/._Bill_Graham_0003.jpg
#   inflating: attendance/Bill_Graham/Bill_Graham_0002.jpg
#   inflating: __MACOSX/attendance/Bill_Graham/._Bill_Graham_0002.jpg
#   inflating: attendance/Bill_Graham/Bill_Graham_0001.jpg
#   inflating: __MACOSX/attendance/Bill_Graham/._Bill_Graham_0001.jpg
#   inflating: __MACOSX/attendance/._Bill_Graham
#    creating: attendance/Yashwant_Sinha/
#   inflating: attendance/Yashwant_Sinha/Yashwant_Sinha_0007.jpg
#    creating: __MACOSX/attendance/Yashwant_Sinha/
#   inflating: __MACOSX/attendance/Yashwant_Sinha/._Yashwant_Sinha_0007.jpg
#   inflating: attendance/Yashwant_Sinha/Yashwant_Sinha_0006.jpg
#   inflating: __MACOSX/attendance/Yashwant_Sinha/._Yashwant_Sinha_0006.jpg
#   inflating: attendance/Yashwant_Sinha/Yashwant_Sinha_0004.jpg
#   inflating: __MACOSX/attendance/Yashwant_Sinha/._Yashwant_Sinha_0004.jpg
#   inflating: attendance/Yashwant_Sinha/Yashwant_Sinha_0005.jpg
#   inflating: __MACOSX/attendance/Yashwant_Sinha/._Yashwant_Sinha_0005.jpg
#   inflating: attendance/Yashwant_Sinha/Yashwant_Sinha_0001.jpg
#   inflating: __MACOSX/attendance/Yashwant_Sinha/._Yashwant_Sinha_0001.jpg
#   inflating: attendance/Yashwant_Sinha/Yashwant_Sinha_0002.jpg
#   inflating: __MACOSX/attendance/Yashwant_Sinha/._Yashwant_Sinha_0002.jpg
#   inflating: attendance/Yashwant_Sinha/Yashwant_Sinha_0003.jpg
#   inflating: __MACOSX/attendance/Yashwant_Sinha/._Yashwant_Sinha_0003.jpg
#   inflating: __MACOSX/attendance/._Yashwant_Sinha
#    creating: attendance/Gloria_Macapagal_Arroyo/
#   inflating: attendance/Gloria_Macapagal_Arroyo/Gloria_Macapagal_Arroyo_0017.jpg
#    creating: __MACOSX/attendance/Gloria_Macapagal_Arroyo/
#   inflating: __MACOSX/attendance/Gloria_Macapagal_Arroyo/._Gloria_Macapagal_Arroyo_0017.jpg
#   inflating: attendance/Gloria_Macapagal_Arroyo/Gloria_Macapagal_Arroyo_0003.jpg
#   inflating: __MACOSX/attendance/Gloria_Macapagal_Arroyo/._Gloria_Macapagal_Arroyo_0003.jpg
#   inflating: attendance/Gloria_Macapagal_Arroyo/Gloria_Macapagal_Arroyo_0002.jpg
#   inflating: __MACOSX/attendance/Gloria_Macapagal_Arroyo/._Gloria_Macapagal_Arroyo_0002.jpg
#   inflating: attendance/Gloria_Macapagal_Arroyo/Gloria_Macapagal_Arroyo_0016.jpg
#   inflating: __MACOSX/attendance/Gloria_Macapagal_Arroyo/._Gloria_Macapagal_Arroyo_0016.jpg
#   inflating: attendance/Gloria_Macapagal_Arroyo/Gloria_Macapagal_Arroyo_0014.jpg
#   inflating: __MACOSX/attendance/Gloria_Macapagal_Arroyo/._Gloria_Macapagal_Arroyo_0014.jpg
#   inflating: attendance/Gloria_Macapagal_Arroyo/Gloria_Macapagal_Arroyo_0028.jpg
#   inflating: __MACOSX/attendance/Gloria_Macapagal_Arroyo/._Gloria_Macapagal_Arroyo_0028.jpg
#   inflating: attendance/Gloria_Macapagal_Arroyo/Gloria_Macapagal_Arroyo_0029.jpg
#   inflating: __MACOSX/attendance/Gloria_Macapagal_Arroyo/._Gloria_Macapagal_Arroyo_0029.jpg
#   inflating: attendance/Gloria_Macapagal_Arroyo/Gloria_Macapagal_Arroyo_0015.jpg
#   inflating: __MACOSX/attendance/Gloria_Macapagal_Arroyo/._Gloria_Macapagal_Arroyo_0015.jpg
#   inflating: attendance/Gloria_Macapagal_Arroyo/Gloria_Macapagal_Arroyo_0001.jpg
#   inflating: __MACOSX/attendance/Gloria_Macapagal_Arroyo/._Gloria_Macapagal_Arroyo_0001.jpg
#   inflating: attendance/Gloria_Macapagal_Arroyo/Gloria_Macapagal_Arroyo_0039.jpg
#   inflating: __MACOSX/attendance/Gloria_Macapagal_Arroyo/._Gloria_Macapagal_Arroyo_0039.jpg
#   inflating: attendance/Gloria_Macapagal_Arroyo/Gloria_Macapagal_Arroyo_0005.jpg
#   inflating: __MACOSX/attendance/Gloria_Macapagal_Arroyo/._Gloria_Macapagal_Arroyo_0005.jpg
#   inflating: attendance/Gloria_Macapagal_Arroyo/Gloria_Macapagal_Arroyo_0011.jpg
#   inflating: __MACOSX/attendance/Gloria_Macapagal_Arroyo/._Gloria_Macapagal_Arroyo_0011.jpg
#   inflating: attendance/Gloria_Macapagal_Arroyo/Gloria_Macapagal_Arroyo_0010.jpg
#   inflating: __MACOSX/attendance/Gloria_Macapagal_Arroyo/._Gloria_Macapagal_Arroyo_0010.jpg
#   inflating: attendance/Gloria_Macapagal_Arroyo/Gloria_Macapagal_Arroyo_0004.jpg
#   inflating: __MACOSX/attendance/Gloria_Macapagal_Arroyo/._Gloria_Macapagal_Arroyo_0004.jpg
#   inflating: attendance/Gloria_Macapagal_Arroyo/Gloria_Macapagal_Arroyo_0038.jpg
#   inflating: __MACOSX/attendance/Gloria_Macapagal_Arroyo/._Gloria_Macapagal_Arroyo_0038.jpg
#   inflating: attendance/Gloria_Macapagal_Arroyo/Gloria_Macapagal_Arroyo_0012.jpg
#   inflating: __MACOSX/attendance/Gloria_Macapagal_Arroyo/._Gloria_Macapagal_Arroyo_0012.jpg
#   inflating: attendance/Gloria_Macapagal_Arroyo/Gloria_Macapagal_Arroyo_0006.jpg
#   inflating: __MACOSX/attendance/Gloria_Macapagal_Arroyo/._Gloria_Macapagal_Arroyo_0006.jpg
#   inflating: attendance/Gloria_Macapagal_Arroyo/Gloria_Macapagal_Arroyo_0007.jpg
#   inflating: __MACOSX/attendance/Gloria_Macapagal_Arroyo/._Gloria_Macapagal_Arroyo_0007.jpg
#   inflating: attendance/Gloria_Macapagal_Arroyo/Gloria_Macapagal_Arroyo_0013.jpg
#   inflating: __MACOSX/attendance/Gloria_Macapagal_Arroyo/._Gloria_Macapagal_Arroyo_0013.jpg
#   inflating: attendance/Gloria_Macapagal_Arroyo/Gloria_Macapagal_Arroyo_0036.jpg
#   inflating: __MACOSX/attendance/Gloria_Macapagal_Arroyo/._Gloria_Macapagal_Arroyo_0036.jpg
#   inflating: attendance/Gloria_Macapagal_Arroyo/Gloria_Macapagal_Arroyo_0022.jpg
#   inflating: __MACOSX/attendance/Gloria_Macapagal_Arroyo/._Gloria_Macapagal_Arroyo_0022.jpg
#   inflating: attendance/Gloria_Macapagal_Arroyo/Gloria_Macapagal_Arroyo_0023.jpg
#   inflating: __MACOSX/attendance/Gloria_Macapagal_Arroyo/._Gloria_Macapagal_Arroyo_0023.jpg
#   inflating: attendance/Gloria_Macapagal_Arroyo/Gloria_Macapagal_Arroyo_0037.jpg
#   inflating: __MACOSX/attendance/Gloria_Macapagal_Arroyo/._Gloria_Macapagal_Arroyo_0037.jpg
#   inflating: attendance/Gloria_Macapagal_Arroyo/Gloria_Macapagal_Arroyo_0021.jpg
#   inflating: __MACOSX/attendance/Gloria_Macapagal_Arroyo/._Gloria_Macapagal_Arroyo_0021.jpg
#   inflating: attendance/Gloria_Macapagal_Arroyo/Gloria_Macapagal_Arroyo_0035.jpg
#   inflating: __MACOSX/attendance/Gloria_Macapagal_Arroyo/._Gloria_Macapagal_Arroyo_0035.jpg
#   inflating: attendance/Gloria_Macapagal_Arroyo/Gloria_Macapagal_Arroyo_0009.jpg
#   inflating: __MACOSX/attendance/Gloria_Macapagal_Arroyo/._Gloria_Macapagal_Arroyo_0009.jpg
#   inflating: attendance/Gloria_Macapagal_Arroyo/Gloria_Macapagal_Arroyo_0008.jpg
#   inflating: __MACOSX/attendance/Gloria_Macapagal_Arroyo/._Gloria_Macapagal_Arroyo_0008.jpg
#   inflating: attendance/Gloria_Macapagal_Arroyo/Gloria_Macapagal_Arroyo_0034.jpg
#   inflating: __MACOSX/attendance/Gloria_Macapagal_Arroyo/._Gloria_Macapagal_Arroyo_0034.jpg
#   inflating: attendance/Gloria_Macapagal_Arroyo/Gloria_Macapagal_Arroyo_0020.jpg
#   inflating: __MACOSX/attendance/Gloria_Macapagal_Arroyo/._Gloria_Macapagal_Arroyo_0020.jpg
#   inflating: attendance/Gloria_Macapagal_Arroyo/Gloria_Macapagal_Arroyo_0018.jpg
#   inflating: __MACOSX/attendance/Gloria_Macapagal_Arroyo/._Gloria_Macapagal_Arroyo_0018.jpg
#   inflating: attendance/Gloria_Macapagal_Arroyo/Gloria_Macapagal_Arroyo_0024.jpg
#   inflating: __MACOSX/attendance/Gloria_Macapagal_Arroyo/._Gloria_Macapagal_Arroyo_0024.jpg
#   inflating: attendance/Gloria_Macapagal_Arroyo/Gloria_Macapagal_Arroyo_0030.jpg
#   inflating: __MACOSX/attendance/Gloria_Macapagal_Arroyo/._Gloria_Macapagal_Arroyo_0030.jpg
#   inflating: attendance/Gloria_Macapagal_Arroyo/Gloria_Macapagal_Arroyo_0031.jpg
#   inflating: __MACOSX/attendance/Gloria_Macapagal_Arroyo/._Gloria_Macapagal_Arroyo_0031.jpg
#   inflating: attendance/Gloria_Macapagal_Arroyo/Gloria_Macapagal_Arroyo_0025.jpg
#   inflating: __MACOSX/attendance/Gloria_Macapagal_Arroyo/._Gloria_Macapagal_Arroyo_0025.jpg
#   inflating: attendance/Gloria_Macapagal_Arroyo/Gloria_Macapagal_Arroyo_0019.jpg
#   inflating: __MACOSX/attendance/Gloria_Macapagal_Arroyo/._Gloria_Macapagal_Arroyo_0019.jpg
#   inflating: attendance/Gloria_Macapagal_Arroyo/Gloria_Macapagal_Arroyo_0033.jpg
#   inflating: __MACOSX/attendance/Gloria_Macapagal_Arroyo/._Gloria_Macapagal_Arroyo_0033.jpg
#   inflating: attendance/Gloria_Macapagal_Arroyo/Gloria_Macapagal_Arroyo_0027.jpg
#   inflating: __MACOSX/attendance/Gloria_Macapagal_Arroyo/._Gloria_Macapagal_Arroyo_0027.jpg
#   inflating: attendance/Gloria_Macapagal_Arroyo/Gloria_Macapagal_Arroyo_0026.jpg
#   inflating: __MACOSX/attendance/Gloria_Macapagal_Arroyo/._Gloria_Macapagal_Arroyo_0026.jpg
#   inflating: attendance/Gloria_Macapagal_Arroyo/Gloria_Macapagal_Arroyo_0032.jpg
#   inflating: __MACOSX/attendance/Gloria_Macapagal_Arroyo/._Gloria_Macapagal_Arroyo_0032.jpg
#   inflating: attendance/Gloria_Macapagal_Arroyo/Gloria_Macapagal_Arroyo_0041.jpg
#   inflating: __MACOSX/attendance/Gloria_Macapagal_Arroyo/._Gloria_Macapagal_Arroyo_0041.jpg
#   inflating: attendance/Gloria_Macapagal_Arroyo/Gloria_Macapagal_Arroyo_0040.jpg
#   inflating: __MACOSX/attendance/Gloria_Macapagal_Arroyo/._Gloria_Macapagal_Arroyo_0040.jpg
#   inflating: attendance/Gloria_Macapagal_Arroyo/Gloria_Macapagal_Arroyo_0042.jpg
#   inflating: __MACOSX/attendance/Gloria_Macapagal_Arroyo/._Gloria_Macapagal_Arroyo_0042.jpg
#   inflating: attendance/Gloria_Macapagal_Arroyo/Gloria_Macapagal_Arroyo_0043.jpg
#   inflating: __MACOSX/attendance/Gloria_Macapagal_Arroyo/._Gloria_Macapagal_Arroyo_0043.jpg
#   inflating: attendance/Gloria_Macapagal_Arroyo/Gloria_Macapagal_Arroyo_0044.jpg
#   inflating: __MACOSX/attendance/Gloria_Macapagal_Arroyo/._Gloria_Macapagal_Arroyo_0044.jpg
#   inflating: __MACOSX/attendance/._Gloria_Macapagal_Arroyo
#    creating: attendance/George_Pataki/
#   inflating: attendance/George_Pataki/George_Pataki_0004.jpg
#    creating: __MACOSX/attendance/George_Pataki/
#   inflating: __MACOSX/attendance/George_Pataki/._George_Pataki_0004.jpg
#   inflating: attendance/George_Pataki/George_Pataki_0005.jpg
#   inflating: __MACOSX/attendance/George_Pataki/._George_Pataki_0005.jpg
#   inflating: attendance/George_Pataki/George_Pataki_0001.jpg
#   inflating: __MACOSX/attendance/George_Pataki/._George_Pataki_0001.jpg
#   inflating: attendance/George_Pataki/George_Pataki_0002.jpg
#   inflating: __MACOSX/attendance/George_Pataki/._George_Pataki_0002.jpg
#   inflating: attendance/George_Pataki/George_Pataki_0003.jpg
#   inflating: __MACOSX/attendance/George_Pataki/._George_Pataki_0003.jpg
#   inflating: __MACOSX/attendance/._George_Pataki
#    creating: attendance/zzVariations_lever0/
#   inflating: attendance/zzVariations_lever0/Unknown.jpg
#    creating: __MACOSX/attendance/zzVariations_lever0/
#   inflating: __MACOSX/attendance/zzVariations_lever0/._Unknown.jpg
#   inflating: attendance/zzVariations_lever0/jimmy-moses-22a99854-87a8-4357-90f6-1ce1884181d-resize-750.jpg
#   inflating: __MACOSX/attendance/zzVariations_lever0/._jimmy-moses-22a99854-87a8-4357-90f6-1ce1884181d-resize-750.jpg
#   inflating: attendance/zzVariations_lever0/1266530.jpg
#   inflating: __MACOSX/attendance/zzVariations_lever0/._1266530.jpg
#   inflating: attendance/zzVariations_lever0/64418.jpg
#   inflating: __MACOSX/attendance/zzVariations_lever0/._64418.jpg
#   inflating: attendance/zzVariations_lever0/960230_10151683175064479_1796506511_n.jpg
#   inflating: __MACOSX/attendance/zzVariations_lever0/._960230_10151683175064479_1796506511_n.jpg
#   inflating: attendance/zzVariations_lever0/3139_200x200.jpg
#   inflating: __MACOSX/attendance/zzVariations_lever0/._3139_200x200.jpg
#    creating: attendance/King_Abdullah_II/
#   inflating: attendance/King_Abdullah_II/King_Abdullah_II_0001.jpg
#    creating: __MACOSX/attendance/King_Abdullah_II/
#   inflating: __MACOSX/attendance/King_Abdullah_II/._King_Abdullah_II_0001.jpg
#   inflating: attendance/King_Abdullah_II/King_Abdullah_II_0002.jpg
#   inflating: __MACOSX/attendance/King_Abdullah_II/._King_Abdullah_II_0002.jpg
#   inflating: attendance/King_Abdullah_II/King_Abdullah_II_0003.jpg
#   inflating: __MACOSX/attendance/King_Abdullah_II/._King_Abdullah_II_0003.jpg
#   inflating: attendance/King_Abdullah_II/King_Abdullah_II_0004.jpg
#   inflating: __MACOSX/attendance/King_Abdullah_II/._King_Abdullah_II_0004.jpg
#   inflating: attendance/King_Abdullah_II/King_Abdullah_II_0005.jpg
#   inflating: __MACOSX/attendance/King_Abdullah_II/._King_Abdullah_II_0005.jpg
#   inflating: __MACOSX/attendance/._King_Abdullah_II
#    creating: attendance/John_Manley/
#   inflating: attendance/John_Manley/John_Manley_0001.jpg
#    creating: __MACOSX/attendance/John_Manley/
#   inflating: __MACOSX/attendance/John_Manley/._John_Manley_0001.jpg
#   inflating: attendance/John_Manley/John_Manley_0003.jpg
#   inflating: __MACOSX/attendance/John_Manley/._John_Manley_0003.jpg
#   inflating: attendance/John_Manley/John_Manley_0002.jpg
#   inflating: __MACOSX/attendance/John_Manley/._John_Manley_0002.jpg
#   inflating: attendance/John_Manley/John_Manley_0006.jpg
#   inflating: __MACOSX/attendance/John_Manley/._John_Manley_0006.jpg
#   inflating: attendance/John_Manley/John_Manley_0007.jpg
#   inflating: __MACOSX/attendance/John_Manley/._John_Manley_0007.jpg
#   inflating: attendance/John_Manley/John_Manley_0005.jpg
#   inflating: __MACOSX/attendance/John_Manley/._John_Manley_0005.jpg
#   inflating: attendance/John_Manley/John_Manley_0004.jpg
#   inflating: __MACOSX/attendance/John_Manley/._John_Manley_0004.jpg
#   inflating: __MACOSX/attendance/._John_Manley
#    creating: attendance/Steven_Spielberg/
#   inflating: attendance/Steven_Spielberg/Steven_Spielberg_0003.jpg
#    creating: __MACOSX/attendance/Steven_Spielberg/
#   inflating: __MACOSX/attendance/Steven_Spielberg/._Steven_Spielberg_0003.jpg
#   inflating: attendance/Steven_Spielberg/Steven_Spielberg_0002.jpg
#   inflating: __MACOSX/attendance/Steven_Spielberg/._Steven_Spielberg_0002.jpg
#   inflating: attendance/Steven_Spielberg/Steven_Spielberg_0001.jpg
#   inflating: __MACOSX/attendance/Steven_Spielberg/._Steven_Spielberg_0001.jpg
#   inflating: attendance/Steven_Spielberg/Steven_Spielberg_0005.jpg
#   inflating: __MACOSX/attendance/Steven_Spielberg/._Steven_Spielberg_0005.jpg
#   inflating: attendance/Steven_Spielberg/Steven_Spielberg_0004.jpg
#   inflating: __MACOSX/attendance/Steven_Spielberg/._Steven_Spielberg_0004.jpg
#   inflating: attendance/Steven_Spielberg/Steven_Spielberg_0006.jpg
#   inflating: __MACOSX/attendance/Steven_Spielberg/._Steven_Spielberg_0006.jpg
#   inflating: attendance/Steven_Spielberg/Steven_Spielberg_0007.jpg
#   inflating: __MACOSX/attendance/Steven_Spielberg/._Steven_Spielberg_0007.jpg
#   inflating: __MACOSX/attendance/._Steven_Spielberg
#    creating: attendance/John_Malkovich/
#   inflating: attendance/John_Malkovich/John_Malkovich_0002.jpg
#    creating: __MACOSX/attendance/John_Malkovich/
#   inflating: __MACOSX/attendance/John_Malkovich/._John_Malkovich_0002.jpg
#   inflating: attendance/John_Malkovich/John_Malkovich_0003.jpg
#   inflating: __MACOSX/attendance/John_Malkovich/._John_Malkovich_0003.jpg
#   inflating: attendance/John_Malkovich/John_Malkovich_0001.jpg
#   inflating: __MACOSX/attendance/John_Malkovich/._John_Malkovich_0001.jpg
#   inflating: __MACOSX/attendance/._John_Malkovich
#    creating: attendance/Martin_Verkerk/
#   inflating: attendance/Martin_Verkerk/Martin_Verkerk_0001.jpg
#    creating: __MACOSX/attendance/Martin_Verkerk/
#   inflating: __MACOSX/attendance/Martin_Verkerk/._Martin_Verkerk_0001.jpg
#   inflating: attendance/Martin_Verkerk/Martin_Verkerk_0002.jpg
#   inflating: __MACOSX/attendance/Martin_Verkerk/._Martin_Verkerk_0002.jpg
#   inflating: attendance/Martin_Verkerk/Martin_Verkerk_0003.jpg
#   inflating: __MACOSX/attendance/Martin_Verkerk/._Martin_Verkerk_0003.jpg
#   inflating: __MACOSX/attendance/._Martin_Verkerk
#    creating: attendance/Bill_Gates/
#   inflating: attendance/Bill_Gates/Bill_Gates_0008.jpg
#    creating: __MACOSX/attendance/Bill_Gates/
#   inflating: __MACOSX/attendance/Bill_Gates/._Bill_Gates_0008.jpg
#   inflating: attendance/Bill_Gates/Bill_Gates_0009.jpg
#   inflating: __MACOSX/attendance/Bill_Gates/._Bill_Gates_0009.jpg
#   inflating: attendance/Bill_Gates/Bill_Gates_0001.jpg
#   inflating: __MACOSX/attendance/Bill_Gates/._Bill_Gates_0001.jpg
#   inflating: attendance/Bill_Gates/Bill_Gates_0015.jpg
#   inflating: __MACOSX/attendance/Bill_Gates/._Bill_Gates_0015.jpg
#   inflating: attendance/Bill_Gates/Bill_Gates_0014.jpg
#   inflating: __MACOSX/attendance/Bill_Gates/._Bill_Gates_0014.jpg
#   inflating: attendance/Bill_Gates/Bill_Gates_0016.jpg
#   inflating: __MACOSX/attendance/Bill_Gates/._Bill_Gates_0016.jpg
#   inflating: attendance/Bill_Gates/Bill_Gates_0002.jpg
#   inflating: __MACOSX/attendance/Bill_Gates/._Bill_Gates_0002.jpg
#   inflating: attendance/Bill_Gates/Bill_Gates_0003.jpg
#   inflating: __MACOSX/attendance/Bill_Gates/._Bill_Gates_0003.jpg
#   inflating: attendance/Bill_Gates/Bill_Gates_0017.jpg
#   inflating: __MACOSX/attendance/Bill_Gates/._Bill_Gates_0017.jpg
#   inflating: attendance/Bill_Gates/Bill_Gates_0013.jpg
#   inflating: __MACOSX/attendance/Bill_Gates/._Bill_Gates_0013.jpg
#   inflating: attendance/Bill_Gates/Bill_Gates_0007.jpg
#   inflating: __MACOSX/attendance/Bill_Gates/._Bill_Gates_0007.jpg
#   inflating: attendance/Bill_Gates/Bill_Gates_0006.jpg
#   inflating: __MACOSX/attendance/Bill_Gates/._Bill_Gates_0006.jpg
#   inflating: attendance/Bill_Gates/Bill_Gates_0012.jpg
#   inflating: __MACOSX/attendance/Bill_Gates/._Bill_Gates_0012.jpg
#   inflating: attendance/Bill_Gates/Bill_Gates_0004.jpg
#   inflating: __MACOSX/attendance/Bill_Gates/._Bill_Gates_0004.jpg
#   inflating: attendance/Bill_Gates/Bill_Gates_0010.jpg
#   inflating: __MACOSX/attendance/Bill_Gates/._Bill_Gates_0010.jpg
#   inflating: attendance/Bill_Gates/Bill_Gates_0011.jpg
#   inflating: __MACOSX/attendance/Bill_Gates/._Bill_Gates_0011.jpg
#   inflating: attendance/Bill_Gates/Bill_Gates_0005.jpg
#   inflating: __MACOSX/attendance/Bill_Gates/._Bill_Gates_0005.jpg
#   inflating: __MACOSX/attendance/._Bill_Gates
#    creating: attendance/Fred_Eckhard/
#   inflating: attendance/Fred_Eckhard/Fred_Eckhard_0003.jpg
#    creating: __MACOSX/attendance/Fred_Eckhard/
#   inflating: __MACOSX/attendance/Fred_Eckhard/._Fred_Eckhard_0003.jpg
#   inflating: attendance/Fred_Eckhard/Fred_Eckhard_0002.jpg
#   inflating: __MACOSX/attendance/Fred_Eckhard/._Fred_Eckhard_0002.jpg
#   inflating: attendance/Fred_Eckhard/Fred_Eckhard_0001.jpg
#   inflating: __MACOSX/attendance/Fred_Eckhard/._Fred_Eckhard_0001.jpg
#   inflating: __MACOSX/attendance/._Fred_Eckhard
#    creating: attendance/Scott_Peterson/
#   inflating: attendance/Scott_Peterson/Scott_Peterson_0002.jpg
#    creating: __MACOSX/attendance/Scott_Peterson/
#   inflating: __MACOSX/attendance/Scott_Peterson/._Scott_Peterson_0002.jpg
#   inflating: attendance/Scott_Peterson/Scott_Peterson_0003.jpg
#   inflating: __MACOSX/attendance/Scott_Peterson/._Scott_Peterson_0003.jpg
#   inflating: attendance/Scott_Peterson/Scott_Peterson_0001.jpg
#   inflating: __MACOSX/attendance/Scott_Peterson/._Scott_Peterson_0001.jpg
#   inflating: attendance/Scott_Peterson/Scott_Peterson_0004.jpg
#   inflating: __MACOSX/attendance/Scott_Peterson/._Scott_Peterson_0004.jpg
#   inflating: attendance/Scott_Peterson/Scott_Peterson_0005.jpg
#   inflating: __MACOSX/attendance/Scott_Peterson/._Scott_Peterson_0005.jpg
#   inflating: __MACOSX/attendance/._Scott_Peterson
#    creating: attendance/Vladimiro_Montesinos/
#   inflating: attendance/Vladimiro_Montesinos/Vladimiro_Montesinos_0001.jpg
#    creating: __MACOSX/attendance/Vladimiro_Montesinos/
#   inflating: __MACOSX/attendance/Vladimiro_Montesinos/._Vladimiro_Montesinos_0001.jpg
#   inflating: attendance/Vladimiro_Montesinos/Vladimiro_Montesinos_0002.jpg
#   inflating: __MACOSX/attendance/Vladimiro_Montesinos/._Vladimiro_Montesinos_0002.jpg
#   inflating: attendance/Vladimiro_Montesinos/Vladimiro_Montesinos_0003.jpg
#   inflating: __MACOSX/attendance/Vladimiro_Montesinos/._Vladimiro_Montesinos_0003.jpg
#   inflating: __MACOSX/attendance/._Vladimiro_Montesinos
#    creating: attendance/ZZVariations_johan1/
#   inflating: attendance/ZZVariations_johan1/Screenshot 2020-10-02 at 4.01.29 AM.png
#    creating: __MACOSX/attendance/ZZVariations_johan1/
#   inflating: __MACOSX/attendance/ZZVariations_johan1/._Screenshot 2020-10-02 at 4.01.29 AM.png
#   inflating: attendance/ZZVariations_johan1/Screenshot 2020-10-02 at 4.01.19 AM.png
#   inflating: __MACOSX/attendance/ZZVariations_johan1/._Screenshot 2020-10-02 at 4.01.19 AM.png
#   inflating: attendance/ZZVariations_johan1/Screenshot 2020-10-02 at 4.01.42 AM.png
#   inflating: __MACOSX/attendance/ZZVariations_johan1/._Screenshot 2020-10-02 at 4.01.42 AM.png
#   inflating: attendance/ZZVariations_johan1/MV5BMTU1NDMzOTI0N15BMl5BanBnXkFtZTcwODk1MDQ4Nw@@._V1_.jpg
#   inflating: __MACOSX/attendance/ZZVariations_johan1/._MV5BMTU1NDMzOTI0N15BMl5BanBnXkFtZTcwODk1MDQ4Nw@@._V1_.jpg
#    creating: attendance/Gregg_Popovich/
#   inflating: attendance/Gregg_Popovich/Gregg_Popovich_0004.jpg
#    creating: __MACOSX/attendance/Gregg_Popovich/
#   inflating: __MACOSX/attendance/Gregg_Popovich/._Gregg_Popovich_0004.jpg
#   inflating: attendance/Gregg_Popovich/Gregg_Popovich_0005.jpg
#   inflating: __MACOSX/attendance/Gregg_Popovich/._Gregg_Popovich_0005.jpg
#   inflating: attendance/Gregg_Popovich/Gregg_Popovich_0002.jpg
#   inflating: __MACOSX/attendance/Gregg_Popovich/._Gregg_Popovich_0002.jpg
#   inflating: attendance/Gregg_Popovich/Gregg_Popovich_0003.jpg
#   inflating: __MACOSX/attendance/Gregg_Popovich/._Gregg_Popovich_0003.jpg
#   inflating: attendance/Gregg_Popovich/Gregg_Popovich_0001.jpg
#   inflating: __MACOSX/attendance/Gregg_Popovich/._Gregg_Popovich_0001.jpg
#   inflating: __MACOSX/attendance/._Gregg_Popovich
#    creating: attendance/Jim_OBrien/
#   inflating: attendance/Jim_OBrien/Jim_OBrien_0001.jpg
#    creating: __MACOSX/attendance/Jim_OBrien/
#   inflating: __MACOSX/attendance/Jim_OBrien/._Jim_OBrien_0001.jpg
#   inflating: attendance/Jim_OBrien/Jim_OBrien_0003.jpg
#   inflating: __MACOSX/attendance/Jim_OBrien/._Jim_OBrien_0003.jpg
#   inflating: attendance/Jim_OBrien/Jim_OBrien_0002.jpg
#   inflating: __MACOSX/attendance/Jim_OBrien/._Jim_OBrien_0002.jpg
#   inflating: __MACOSX/attendance/._Jim_OBrien
#    creating: attendance/Lucio_Gutierrez/
#   inflating: attendance/Lucio_Gutierrez/Lucio_Gutierrez_0008.jpg
#    creating: __MACOSX/attendance/Lucio_Gutierrez/
#   inflating: __MACOSX/attendance/Lucio_Gutierrez/._Lucio_Gutierrez_0008.jpg
#   inflating: attendance/Lucio_Gutierrez/Lucio_Gutierrez_0009.jpg
#   inflating: __MACOSX/attendance/Lucio_Gutierrez/._Lucio_Gutierrez_0009.jpg
#   inflating: attendance/Lucio_Gutierrez/Lucio_Gutierrez_0001.jpg
#   inflating: __MACOSX/attendance/Lucio_Gutierrez/._Lucio_Gutierrez_0001.jpg
#   inflating: attendance/Lucio_Gutierrez/Lucio_Gutierrez_0002.jpg
#   inflating: __MACOSX/attendance/Lucio_Gutierrez/._Lucio_Gutierrez_0002.jpg
#   inflating: attendance/Lucio_Gutierrez/Lucio_Gutierrez_0003.jpg
#   inflating: __MACOSX/attendance/Lucio_Gutierrez/._Lucio_Gutierrez_0003.jpg
#   inflating: attendance/Lucio_Gutierrez/Lucio_Gutierrez_0013.jpg
#   inflating: __MACOSX/attendance/Lucio_Gutierrez/._Lucio_Gutierrez_0013.jpg
#   inflating: attendance/Lucio_Gutierrez/Lucio_Gutierrez_0007.jpg
#   inflating: __MACOSX/attendance/Lucio_Gutierrez/._Lucio_Gutierrez_0007.jpg
#   inflating: attendance/Lucio_Gutierrez/Lucio_Gutierrez_0006.jpg
#   inflating: __MACOSX/attendance/Lucio_Gutierrez/._Lucio_Gutierrez_0006.jpg
#   inflating: attendance/Lucio_Gutierrez/Lucio_Gutierrez_0012.jpg
#   inflating: __MACOSX/attendance/Lucio_Gutierrez/._Lucio_Gutierrez_0012.jpg
#   inflating: attendance/Lucio_Gutierrez/Lucio_Gutierrez_0004.jpg
#   inflating: __MACOSX/attendance/Lucio_Gutierrez/._Lucio_Gutierrez_0004.jpg
#   inflating: attendance/Lucio_Gutierrez/Lucio_Gutierrez_0010.jpg
#   inflating: __MACOSX/attendance/Lucio_Gutierrez/._Lucio_Gutierrez_0010.jpg
#   inflating: attendance/Lucio_Gutierrez/Lucio_Gutierrez_0011.jpg
#   inflating: __MACOSX/attendance/Lucio_Gutierrez/._Lucio_Gutierrez_0011.jpg
#   inflating: attendance/Lucio_Gutierrez/Lucio_Gutierrez_0005.jpg
#   inflating: __MACOSX/attendance/Lucio_Gutierrez/._Lucio_Gutierrez_0005.jpg
#   inflating: __MACOSX/attendance/._Lucio_Gutierrez
#    creating: attendance/Alejandro_Toledo/
#   inflating: attendance/Alejandro_Toledo/Alejandro_Toledo_0029.jpg
#    creating: __MACOSX/attendance/Alejandro_Toledo/
#   inflating: __MACOSX/attendance/Alejandro_Toledo/._Alejandro_Toledo_0029.jpg
#   inflating: attendance/Alejandro_Toledo/Alejandro_Toledo_0001.jpg
#   inflating: __MACOSX/attendance/Alejandro_Toledo/._Alejandro_Toledo_0001.jpg
#   inflating: attendance/Alejandro_Toledo/Alejandro_Toledo_0015.jpg
#   inflating: __MACOSX/attendance/Alejandro_Toledo/._Alejandro_Toledo_0015.jpg
#   inflating: attendance/Alejandro_Toledo/Alejandro_Toledo_0014.jpg
#   inflating: __MACOSX/attendance/Alejandro_Toledo/._Alejandro_Toledo_0014.jpg
#   inflating: attendance/Alejandro_Toledo/Alejandro_Toledo_0028.jpg
#   inflating: __MACOSX/attendance/Alejandro_Toledo/._Alejandro_Toledo_0028.jpg
#   inflating: attendance/Alejandro_Toledo/Alejandro_Toledo_0016.jpg
#   inflating: __MACOSX/attendance/Alejandro_Toledo/._Alejandro_Toledo_0016.jpg
#   inflating: attendance/Alejandro_Toledo/Alejandro_Toledo_0002.jpg
#   inflating: __MACOSX/attendance/Alejandro_Toledo/._Alejandro_Toledo_0002.jpg
#   inflating: attendance/Alejandro_Toledo/Alejandro_Toledo_0003.jpg
#   inflating: __MACOSX/attendance/Alejandro_Toledo/._Alejandro_Toledo_0003.jpg
#   inflating: attendance/Alejandro_Toledo/Alejandro_Toledo_0017.jpg
#   inflating: __MACOSX/attendance/Alejandro_Toledo/._Alejandro_Toledo_0017.jpg
#   inflating: attendance/Alejandro_Toledo/Alejandro_Toledo_0013.jpg
#   inflating: __MACOSX/attendance/Alejandro_Toledo/._Alejandro_Toledo_0013.jpg
#   inflating: attendance/Alejandro_Toledo/Alejandro_Toledo_0007.jpg
#   inflating: __MACOSX/attendance/Alejandro_Toledo/._Alejandro_Toledo_0007.jpg
#   inflating: attendance/Alejandro_Toledo/Alejandro_Toledo_0006.jpg
#   inflating: __MACOSX/attendance/Alejandro_Toledo/._Alejandro_Toledo_0006.jpg
#   inflating: attendance/Alejandro_Toledo/Alejandro_Toledo_0012.jpg
#   inflating: __MACOSX/attendance/Alejandro_Toledo/._Alejandro_Toledo_0012.jpg
#   inflating: attendance/Alejandro_Toledo/Alejandro_Toledo_0004.jpg
#   inflating: __MACOSX/attendance/Alejandro_Toledo/._Alejandro_Toledo_0004.jpg
#   inflating: attendance/Alejandro_Toledo/Alejandro_Toledo_0010.jpg
#   inflating: __MACOSX/attendance/Alejandro_Toledo/._Alejandro_Toledo_0010.jpg
#   inflating: attendance/Alejandro_Toledo/Alejandro_Toledo_0038.jpg
#   inflating: __MACOSX/attendance/Alejandro_Toledo/._Alejandro_Toledo_0038.jpg
#   inflating: attendance/Alejandro_Toledo/Alejandro_Toledo_0039.jpg
#   inflating: __MACOSX/attendance/Alejandro_Toledo/._Alejandro_Toledo_0039.jpg
#   inflating: attendance/Alejandro_Toledo/Alejandro_Toledo_0011.jpg
#   inflating: __MACOSX/attendance/Alejandro_Toledo/._Alejandro_Toledo_0011.jpg
#   inflating: attendance/Alejandro_Toledo/Alejandro_Toledo_0005.jpg
#   inflating: __MACOSX/attendance/Alejandro_Toledo/._Alejandro_Toledo_0005.jpg
#   inflating: attendance/Alejandro_Toledo/Alejandro_Toledo_0008.jpg
#   inflating: __MACOSX/attendance/Alejandro_Toledo/._Alejandro_Toledo_0008.jpg
#   inflating: attendance/Alejandro_Toledo/Alejandro_Toledo_0020.jpg
#   inflating: __MACOSX/attendance/Alejandro_Toledo/._Alejandro_Toledo_0020.jpg
#   inflating: attendance/Alejandro_Toledo/Alejandro_Toledo_0034.jpg
#   inflating: __MACOSX/attendance/Alejandro_Toledo/._Alejandro_Toledo_0034.jpg
#   inflating: attendance/Alejandro_Toledo/Alejandro_Toledo_0035.jpg
#   inflating: __MACOSX/attendance/Alejandro_Toledo/._Alejandro_Toledo_0035.jpg
#   inflating: attendance/Alejandro_Toledo/Alejandro_Toledo_0021.jpg
#   inflating: __MACOSX/attendance/Alejandro_Toledo/._Alejandro_Toledo_0021.jpg
#   inflating: attendance/Alejandro_Toledo/Alejandro_Toledo_0009.jpg
#   inflating: __MACOSX/attendance/Alejandro_Toledo/._Alejandro_Toledo_0009.jpg
# ...
#   inflating: __MACOSX/attendance/John_Ashcroft/._John_Ashcroft_0031.jpg
#   inflating: attendance/John_Ashcroft/John_Ashcroft_0030.jpg
#   inflating: __MACOSX/attendance/John_Ashcroft/._John_Ashcroft_0030.jpg
#   inflating: attendance/John_Ashcroft/John_Ashcroft_0024.jpg
#   inflating: __MACOSX/attendance/John_Ashcroft/._John_Ashcroft_0024.jpg
#   inflating: attendance/John_Ashcroft/John_Ashcroft_0018.jpg
#   inflating: __MACOSX/attendance/John_Ashcroft/._John_Ashcroft_0018.jpg
#   inflating: attendance/John_Ashcroft/John_Ashcroft_0032.jpg
#   inflating: __MACOSX/attendance/John_Ashcroft/._John_Ashcroft_0032.jpg
#   inflating: attendance/John_Ashcroft/John_Ashcroft_0026.jpg
#   inflating: __MACOSX/attendance/John_Ashcroft/._John_Ashcroft_0026.jpg
#   inflating: attendance/John_Ashcroft/John_Ashcroft_0027.jpg
#   inflating: __MACOSX/attendance/John_Ashcroft/._John_Ashcroft_0027.jpg
#   inflating: attendance/John_Ashcroft/John_Ashcroft_0033.jpg
#   inflating: __MACOSX/attendance/John_Ashcroft/._John_Ashcroft_0033.jpg
#   inflating: attendance/John_Ashcroft/John_Ashcroft_0037.jpg
#   inflating: __MACOSX/attendance/John_Ashcroft/._John_Ashcroft_0037.jpg
#   inflating: attendance/John_Ashcroft/John_Ashcroft_0023.jpg
#   inflating: __MACOSX/attendance/John_Ashcroft/._John_Ashcroft_0023.jpg
#   inflating: attendance/John_Ashcroft/John_Ashcroft_0022.jpg
#   inflating: __MACOSX/attendance/John_Ashcroft/._John_Ashcroft_0022.jpg
#   inflating: attendance/John_Ashcroft/John_Ashcroft_0036.jpg
#   inflating: __MACOSX/attendance/John_Ashcroft/._John_Ashcroft_0036.jpg
#   inflating: attendance/John_Ashcroft/John_Ashcroft_0020.jpg
#   inflating: __MACOSX/attendance/John_Ashcroft/._John_Ashcroft_0020.jpg
#   inflating: attendance/John_Ashcroft/John_Ashcroft_0034.jpg
#   inflating: __MACOSX/attendance/John_Ashcroft/._John_Ashcroft_0034.jpg
#   inflating: attendance/John_Ashcroft/John_Ashcroft_0008.jpg
#   inflating: __MACOSX/attendance/John_Ashcroft/._John_Ashcroft_0008.jpg
#   inflating: attendance/John_Ashcroft/John_Ashcroft_0009.jpg
#   inflating: __MACOSX/attendance/John_Ashcroft/._John_Ashcroft_0009.jpg
#   inflating: attendance/John_Ashcroft/John_Ashcroft_0035.jpg
#   inflating: __MACOSX/attendance/John_Ashcroft/._John_Ashcroft_0035.jpg
#   inflating: attendance/John_Ashcroft/John_Ashcroft_0021.jpg
#   inflating: __MACOSX/attendance/John_Ashcroft/._John_Ashcroft_0021.jpg
#   inflating: __MACOSX/attendance/._John_Ashcroft
#    creating: attendance/Geraldine_Chaplin/
#   inflating: attendance/Geraldine_Chaplin/Geraldine_Chaplin_0002.jpg
#    creating: __MACOSX/attendance/Geraldine_Chaplin/
#   inflating: __MACOSX/attendance/Geraldine_Chaplin/._Geraldine_Chaplin_0002.jpg
#   inflating: attendance/Geraldine_Chaplin/Geraldine_Chaplin_0003.jpg
#   inflating: __MACOSX/attendance/Geraldine_Chaplin/._Geraldine_Chaplin_0003.jpg
#   inflating: attendance/Geraldine_Chaplin/Geraldine_Chaplin_0001.jpg
#   inflating: __MACOSX/attendance/Geraldine_Chaplin/._Geraldine_Chaplin_0001.jpg
#   inflating: attendance/Geraldine_Chaplin/Geraldine_Chaplin_0004.jpg
#   inflating: __MACOSX/attendance/Geraldine_Chaplin/._Geraldine_Chaplin_0004.jpg
#   inflating: __MACOSX/attendance/._Geraldine_Chaplin
#    creating: attendance/Xavier_Malisse/
#   inflating: attendance/Xavier_Malisse/Xavier_Malisse_0005.jpg
#    creating: __MACOSX/attendance/Xavier_Malisse/
#   inflating: __MACOSX/attendance/Xavier_Malisse/._Xavier_Malisse_0005.jpg
#   inflating: attendance/Xavier_Malisse/Xavier_Malisse_0004.jpg
#   inflating: __MACOSX/attendance/Xavier_Malisse/._Xavier_Malisse_0004.jpg
#   inflating: attendance/Xavier_Malisse/Xavier_Malisse_0003.jpg
#   inflating: __MACOSX/attendance/Xavier_Malisse/._Xavier_Malisse_0003.jpg
#   inflating: attendance/Xavier_Malisse/Xavier_Malisse_0002.jpg
#   inflating: __MACOSX/attendance/Xavier_Malisse/._Xavier_Malisse_0002.jpg
#   inflating: attendance/Xavier_Malisse/Xavier_Malisse_0001.jpg
#   inflating: __MACOSX/attendance/Xavier_Malisse/._Xavier_Malisse_0001.jpg
#   inflating: __MACOSX/attendance/._Xavier_Malisse
#    creating: attendance/Michael_Caine/
#   inflating: attendance/Michael_Caine/Michael_Caine_0003.jpg
#    creating: __MACOSX/attendance/Michael_Caine/
#   inflating: __MACOSX/attendance/Michael_Caine/._Michael_Caine_0003.jpg
#   inflating: attendance/Michael_Caine/Michael_Caine_0002.jpg
#   inflating: __MACOSX/attendance/Michael_Caine/._Michael_Caine_0002.jpg
#   inflating: attendance/Michael_Caine/Michael_Caine_0001.jpg
#   inflating: __MACOSX/attendance/Michael_Caine/._Michael_Caine_0001.jpg
#   inflating: attendance/Michael_Caine/Michael_Caine_0004.jpg
#   inflating: __MACOSX/attendance/Michael_Caine/._Michael_Caine_0004.jpg
#   inflating: __MACOSX/attendance/._Michael_Caine
#    creating: attendance/Dominique_de_Villepin/
#   inflating: attendance/Dominique_de_Villepin/Dominique_de_Villepin_0014.jpg
#    creating: __MACOSX/attendance/Dominique_de_Villepin/
#   inflating: __MACOSX/attendance/Dominique_de_Villepin/._Dominique_de_Villepin_0014.jpg
#   inflating: attendance/Dominique_de_Villepin/Dominique_de_Villepin_0015.jpg
#   inflating: __MACOSX/attendance/Dominique_de_Villepin/._Dominique_de_Villepin_0015.jpg
#   inflating: attendance/Dominique_de_Villepin/Dominique_de_Villepin_0001.jpg
#   inflating: __MACOSX/attendance/Dominique_de_Villepin/._Dominique_de_Villepin_0001.jpg
#   inflating: attendance/Dominique_de_Villepin/Dominique_de_Villepin_0003.jpg
#   inflating: __MACOSX/attendance/Dominique_de_Villepin/._Dominique_de_Villepin_0003.jpg
#   inflating: attendance/Dominique_de_Villepin/Dominique_de_Villepin_0002.jpg
#   inflating: __MACOSX/attendance/Dominique_de_Villepin/._Dominique_de_Villepin_0002.jpg
#   inflating: attendance/Dominique_de_Villepin/Dominique_de_Villepin_0012.jpg
#   inflating: __MACOSX/attendance/Dominique_de_Villepin/._Dominique_de_Villepin_0012.jpg
#   inflating: attendance/Dominique_de_Villepin/Dominique_de_Villepin_0006.jpg
#   inflating: __MACOSX/attendance/Dominique_de_Villepin/._Dominique_de_Villepin_0006.jpg
#   inflating: attendance/Dominique_de_Villepin/Dominique_de_Villepin_0007.jpg
#   inflating: __MACOSX/attendance/Dominique_de_Villepin/._Dominique_de_Villepin_0007.jpg
#   inflating: attendance/Dominique_de_Villepin/Dominique_de_Villepin_0013.jpg
#   inflating: __MACOSX/attendance/Dominique_de_Villepin/._Dominique_de_Villepin_0013.jpg
#   inflating: attendance/Dominique_de_Villepin/Dominique_de_Villepin_0005.jpg
#   inflating: __MACOSX/attendance/Dominique_de_Villepin/._Dominique_de_Villepin_0005.jpg
#   inflating: attendance/Dominique_de_Villepin/Dominique_de_Villepin_0011.jpg
#   inflating: __MACOSX/attendance/Dominique_de_Villepin/._Dominique_de_Villepin_0011.jpg
#   inflating: attendance/Dominique_de_Villepin/Dominique_de_Villepin_0010.jpg
#   inflating: __MACOSX/attendance/Dominique_de_Villepin/._Dominique_de_Villepin_0010.jpg
#   inflating: attendance/Dominique_de_Villepin/Dominique_de_Villepin_0004.jpg
#   inflating: __MACOSX/attendance/Dominique_de_Villepin/._Dominique_de_Villepin_0004.jpg
#   inflating: attendance/Dominique_de_Villepin/Dominique_de_Villepin_0009.jpg
#   inflating: __MACOSX/attendance/Dominique_de_Villepin/._Dominique_de_Villepin_0009.jpg
#   inflating: attendance/Dominique_de_Villepin/Dominique_de_Villepin_0008.jpg
#   inflating: __MACOSX/attendance/Dominique_de_Villepin/._Dominique_de_Villepin_0008.jpg
#   inflating: __MACOSX/attendance/._Dominique_de_Villepin
#    creating: attendance/Heinz_Feldmann/
#   inflating: attendance/Heinz_Feldmann/Heinz_Feldmann_0001.jpg
#    creating: __MACOSX/attendance/Heinz_Feldmann/
#   inflating: __MACOSX/attendance/Heinz_Feldmann/._Heinz_Feldmann_0001.jpg
#   inflating: attendance/Heinz_Feldmann/Heinz_Feldmann_0003.jpg
#   inflating: __MACOSX/attendance/Heinz_Feldmann/._Heinz_Feldmann_0003.jpg
#   inflating: attendance/Heinz_Feldmann/Heinz_Feldmann_0002.jpg
#   inflating: __MACOSX/attendance/Heinz_Feldmann/._Heinz_Feldmann_0002.jpg
#   inflating: __MACOSX/attendance/._Heinz_Feldmann
#    creating: attendance/Antonio_Trillanes/
#   inflating: attendance/Antonio_Trillanes/Antonio_Trillanes_0003.jpg
#    creating: __MACOSX/attendance/Antonio_Trillanes/
#   inflating: __MACOSX/attendance/Antonio_Trillanes/._Antonio_Trillanes_0003.jpg
#   inflating: attendance/Antonio_Trillanes/Antonio_Trillanes_0002.jpg
#   inflating: __MACOSX/attendance/Antonio_Trillanes/._Antonio_Trillanes_0002.jpg
#   inflating: attendance/Antonio_Trillanes/Antonio_Trillanes_0001.jpg
#   inflating: __MACOSX/attendance/Antonio_Trillanes/._Antonio_Trillanes_0001.jpg
#   inflating: __MACOSX/attendance/._Antonio_Trillanes
#    creating: attendance/Pascal_Quignard/
#   inflating: attendance/Pascal_Quignard/Pascal_Quignard_0003.jpg
#    creating: __MACOSX/attendance/Pascal_Quignard/
#   inflating: __MACOSX/attendance/Pascal_Quignard/._Pascal_Quignard_0003.jpg
#   inflating: attendance/Pascal_Quignard/Pascal_Quignard_0002.jpg
#   inflating: __MACOSX/attendance/Pascal_Quignard/._Pascal_Quignard_0002.jpg
#   inflating: attendance/Pascal_Quignard/Pascal_Quignard_0001.jpg
#   inflating: __MACOSX/attendance/Pascal_Quignard/._Pascal_Quignard_0001.jpg
#   inflating: __MACOSX/attendance/._Pascal_Quignard
#    creating: attendance/Roger_Federer/
#   inflating: attendance/Roger_Federer/Roger_Federer_0001.jpg
#    creating: __MACOSX/attendance/Roger_Federer/
#   inflating: __MACOSX/attendance/Roger_Federer/._Roger_Federer_0001.jpg
#   inflating: attendance/Roger_Federer/Roger_Federer_0014.jpg
#   inflating: __MACOSX/attendance/Roger_Federer/._Roger_Federer_0014.jpg
#   inflating: attendance/Roger_Federer/Roger_Federer_0002.jpg
#   inflating: __MACOSX/attendance/Roger_Federer/._Roger_Federer_0002.jpg
#   inflating: attendance/Roger_Federer/Roger_Federer_0003.jpg
#   inflating: __MACOSX/attendance/Roger_Federer/._Roger_Federer_0003.jpg
#   inflating: attendance/Roger_Federer/Roger_Federer_0013.jpg
#   inflating: __MACOSX/attendance/Roger_Federer/._Roger_Federer_0013.jpg
#   inflating: attendance/Roger_Federer/Roger_Federer_0007.jpg
#   inflating: __MACOSX/attendance/Roger_Federer/._Roger_Federer_0007.jpg
#   inflating: attendance/Roger_Federer/Roger_Federer_0006.jpg
#   inflating: __MACOSX/attendance/Roger_Federer/._Roger_Federer_0006.jpg
#   inflating: attendance/Roger_Federer/Roger_Federer_0012.jpg
#   inflating: __MACOSX/attendance/Roger_Federer/._Roger_Federer_0012.jpg
#   inflating: attendance/Roger_Federer/Roger_Federer_0004.jpg
#   inflating: __MACOSX/attendance/Roger_Federer/._Roger_Federer_0004.jpg
#   inflating: attendance/Roger_Federer/Roger_Federer_0010.jpg
#   inflating: __MACOSX/attendance/Roger_Federer/._Roger_Federer_0010.jpg
#   inflating: attendance/Roger_Federer/Roger_Federer_0011.jpg
#   inflating: __MACOSX/attendance/Roger_Federer/._Roger_Federer_0011.jpg
#   inflating: attendance/Roger_Federer/Roger_Federer_0005.jpg
#   inflating: __MACOSX/attendance/Roger_Federer/._Roger_Federer_0005.jpg
#   inflating: attendance/Roger_Federer/Roger_Federer_0008.jpg
#   inflating: __MACOSX/attendance/Roger_Federer/._Roger_Federer_0008.jpg
#   inflating: attendance/Roger_Federer/Roger_Federer_0009.jpg
#   inflating: __MACOSX/attendance/Roger_Federer/._Roger_Federer_0009.jpg
#   inflating: __MACOSX/attendance/._Roger_Federer
#    creating: attendance/Norm_Coleman/
#   inflating: attendance/Norm_Coleman/Norm_Coleman_0002.jpg
#    creating: __MACOSX/attendance/Norm_Coleman/
#   inflating: __MACOSX/attendance/Norm_Coleman/._Norm_Coleman_0002.jpg
#   inflating: attendance/Norm_Coleman/Norm_Coleman_0003.jpg
#   inflating: __MACOSX/attendance/Norm_Coleman/._Norm_Coleman_0003.jpg
#   inflating: attendance/Norm_Coleman/Norm_Coleman_0001.jpg
#   inflating: __MACOSX/attendance/Norm_Coleman/._Norm_Coleman_0001.jpg
#   inflating: attendance/Norm_Coleman/Norm_Coleman_0004.jpg
#   inflating: __MACOSX/attendance/Norm_Coleman/._Norm_Coleman_0004.jpg
#   inflating: attendance/Norm_Coleman/Norm_Coleman_0005.jpg
#   inflating: __MACOSX/attendance/Norm_Coleman/._Norm_Coleman_0005.jpg
#   inflating: attendance/Norm_Coleman/Norm_Coleman_0007.jpg
#   inflating: __MACOSX/attendance/Norm_Coleman/._Norm_Coleman_0007.jpg
#   inflating: attendance/Norm_Coleman/Norm_Coleman_0006.jpg
#   inflating: __MACOSX/attendance/Norm_Coleman/._Norm_Coleman_0006.jpg
#   inflating: __MACOSX/attendance/._Norm_Coleman
#    creating: attendance/Tim_Duncan/
#   inflating: attendance/Tim_Duncan/Tim_Duncan_0001.jpg
#    creating: __MACOSX/attendance/Tim_Duncan/
#   inflating: __MACOSX/attendance/Tim_Duncan/._Tim_Duncan_0001.jpg
#   inflating: attendance/Tim_Duncan/Tim_Duncan_0002.jpg
#   inflating: __MACOSX/attendance/Tim_Duncan/._Tim_Duncan_0002.jpg
#   inflating: attendance/Tim_Duncan/Tim_Duncan_0003.jpg
#   inflating: __MACOSX/attendance/Tim_Duncan/._Tim_Duncan_0003.jpg
#   inflating: attendance/Tim_Duncan/Tim_Duncan_0004.jpg
#   inflating: __MACOSX/attendance/Tim_Duncan/._Tim_Duncan_0004.jpg
#   inflating: __MACOSX/attendance/._Tim_Duncan
#    creating: attendance/Enrique_Bolanos/
#   inflating: attendance/Enrique_Bolanos/Enrique_Bolanos_0002.jpg
#    creating: __MACOSX/attendance/Enrique_Bolanos/
#   inflating: __MACOSX/attendance/Enrique_Bolanos/._Enrique_Bolanos_0002.jpg
#   inflating: attendance/Enrique_Bolanos/Enrique_Bolanos_0003.jpg
#   inflating: __MACOSX/attendance/Enrique_Bolanos/._Enrique_Bolanos_0003.jpg
#   inflating: attendance/Enrique_Bolanos/Enrique_Bolanos_0001.jpg
#   inflating: __MACOSX/attendance/Enrique_Bolanos/._Enrique_Bolanos_0001.jpg
#   inflating: attendance/Enrique_Bolanos/Enrique_Bolanos_0004.jpg
#   inflating: __MACOSX/attendance/Enrique_Bolanos/._Enrique_Bolanos_0004.jpg
#   inflating: attendance/Enrique_Bolanos/Enrique_Bolanos_0005.jpg
#   inflating: __MACOSX/attendance/Enrique_Bolanos/._Enrique_Bolanos_0005.jpg
#   inflating: __MACOSX/attendance/._Enrique_Bolanos
#    creating: attendance/zzVariations_franco1/
#   inflating: attendance/zzVariations_franco1/MV5BMjA4MzMzNDM5MF5BMl5BanBnXkFtZTgwMjQ0MDk0NDM@._V1_UY1200_CR85,0,630,1200_AL_.jpg
#    creating: __MACOSX/attendance/zzVariations_franco1/
#   inflating: __MACOSX/attendance/zzVariations_franco1/._MV5BMjA4MzMzNDM5MF5BMl5BanBnXkFtZTgwMjQ0MDk0NDM@._V1_UY1200_CR85,0,630,1200_AL_.jpg
#   inflating: attendance/zzVariations_franco1/James-Franco.jpg
#   inflating: __MACOSX/attendance/zzVariations_franco1/._James-Franco.jpg
#   inflating: attendance/zzVariations_franco1/170px-James_Franco_2007_Spiderman_3_premiere.jpg
#   inflating: __MACOSX/attendance/zzVariations_franco1/._170px-James_Franco_2007_Spiderman_3_premiere.jpg
#   inflating: attendance/zzVariations_franco1/2330.jpg
#   inflating: __MACOSX/attendance/zzVariations_franco1/._2330.jpg
#   inflating: attendance/zzVariations_franco1/90.jpg
#   inflating: __MACOSX/attendance/zzVariations_franco1/._90.jpg
#    creating: attendance/Li_Zhaoxing/
#   inflating: attendance/Li_Zhaoxing/Li_Zhaoxing_0008.jpg
#    creating: __MACOSX/attendance/Li_Zhaoxing/
#   inflating: __MACOSX/attendance/Li_Zhaoxing/._Li_Zhaoxing_0008.jpg
#   inflating: attendance/Li_Zhaoxing/Li_Zhaoxing_0006.jpg
#   inflating: __MACOSX/attendance/Li_Zhaoxing/._Li_Zhaoxing_0006.jpg
#   inflating: attendance/Li_Zhaoxing/Li_Zhaoxing_0007.jpg
#   inflating: __MACOSX/attendance/Li_Zhaoxing/._Li_Zhaoxing_0007.jpg
#   inflating: attendance/Li_Zhaoxing/Li_Zhaoxing_0005.jpg
#   inflating: __MACOSX/attendance/Li_Zhaoxing/._Li_Zhaoxing_0005.jpg
#   inflating: attendance/Li_Zhaoxing/Li_Zhaoxing_0004.jpg
#   inflating: __MACOSX/attendance/Li_Zhaoxing/._Li_Zhaoxing_0004.jpg
#   inflating: attendance/Li_Zhaoxing/Li_Zhaoxing_0001.jpg
#   inflating: __MACOSX/attendance/Li_Zhaoxing/._Li_Zhaoxing_0001.jpg
#   inflating: attendance/Li_Zhaoxing/Li_Zhaoxing_0003.jpg
#   inflating: __MACOSX/attendance/Li_Zhaoxing/._Li_Zhaoxing_0003.jpg
#   inflating: attendance/Li_Zhaoxing/Li_Zhaoxing_0002.jpg
#   inflating: __MACOSX/attendance/Li_Zhaoxing/._Li_Zhaoxing_0002.jpg
#   inflating: __MACOSX/attendance/._Li_Zhaoxing
#   inflating: __MACOSX/._attendance

# %%
import os
employees={}
directory='/content/attendance'
for folder in os.walk(directory):
  employees[folder[0].split('/')[-1]]= [i for i in list(os.walk(folder[0]))[0][-1] if '.jpg' in i or '.jpeg' in i or '.png' in i]

# %%
list(employees.keys())[1]
# Out:
# 'zzVariations_kunis1'

# %%
employeeslist=list(employees.keys())[1:]

# %%
employeeslist.sort()

# %%
employees0=employeeslist[:250]
employees1=employeeslist[250:500]
employees2=employeeslist[500:750]
employees3=employeeslist[750:]

# %%
# !unzip '/content/drive/My Drive/face_models.zip'
# Out:
# Archive:  /content/drive/My Drive/face_models.zip
#    creating: content/models/
#   inflating: content/models/vgg_face_weights.h5
#   inflating: content/models/facenet_weights.h5
#   inflating: content/models/VGGFace2_DeepFace_weights_val-0.9034.h5
#   inflating: content/models/dlib_face_recognition_resnet_model_v1.dat
#   inflating: content/models/openface_weights.h5
#    creating: content/models/.ipynb_checkpoints/

# %%
model = loadModel()
images=[]
metadata=[]
from tqdm import tqdm
import tensorflow as tf
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
tf.get_logger().setLevel('INFO')
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)  # or any {DEBUG, INFO, WARN, ERROR, FATAL}
for k in tqdm(employees2):
  for j in employees[str(k)]:
    temp=[]
    img='/'.join(['/content/attendance',k,j])
    try:
      images.append(path_to_image(img))
      temp.append(k)
      temp.append(img)
      metadata.append(temp)
    except:
      pass
# Out:
#   4%|▍         | 10/250 [01:20<32:22,  8.09s/it]

# %%
import numpy as np
images=np.array(images)

# %%
images.shape
# Out:
# (2763, 1, 160, 160, 3)

# %%
images=images.reshape(2763, 160, 160, 3)

# %%
np.array_equal(images[0],a[0])
# Out:
# True

# %%
vectors=model.predict(images)

# %%
import pickle

with open('images0.arr', 'wb') as handle:
    pickle.dump(images, handle, protocol=pickle.HIGHEST_PROTOCOL)

#with open('filename.pickle', 'rb') as handle:
#    b = pickle.load(handle)

# %%
del images, metadata, vectors
import gc
gc.collect()
# Out:
# 720359

# %%
import psutil
psutil.virtual_memory()
# Out:
# svmem(total=13653557248, available=8172974080, percent=40.1, used=10269978624, free=189792256, active=5602152448, inactive=7368679424, buffers=104173568, cached=3089612800, shared=15683584, slab=242495488)

# %%
# !mkdir attendancedata

# %%
# !mv /content/vectors.arr /content/attendancedata

# %%
# !zip -r attendancedata250.zip /content/attendancedata
# Out:
#   adding: content/attendancedata/ (stored 0%)
#   adding: content/attendancedata/images.arr (deflated 73%)
#   adding: content/attendancedata/vectors.arr (deflated 7%)
#   adding: content/attendancedata/metadata.emp (deflated 92%)

# %%
# !mv /content/attendancedata250.zip '/content/drive/My Drive/'
